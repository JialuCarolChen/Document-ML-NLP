# %%
# %load_ext autoreload
# %autoreload 2
#from raxutil.nlp.faresheet import *
#from raxutil.nlp.production import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import cssutils
from functools import reduce
import os
from os.path import basename
import csv, ast
from glob import glob
from collections import Counter, defaultdict
from nltk.classify import MaxentClassifier 

import pymongo
from pymongo import MongoClient
from pymongo import TEXT
pd.options.display.max_rows = 99999

# %%
client = MongoClient('localhost:27017')
db=client.raxdb
faresheet = 'CXfaresheets_new'
faresheet_old = 'CXfaresheets' 
fs = db['CXfaresheets_new']

# %% [markdown]
# ### Identify different templates of US commission sheets

# %%
us_docs = [doc for doc in fs.find({'country': 'US'}, 
                                  {'predictions':1, 'classifications':1, 'filename':1, 'country':1})]

# %%
len(us_docs)
# Out:
# 1405

# %%
us_df = pd.DataFrame(us_docs)

# %%
for index, row in us_df.iterrows():
    try:
        us_df.loc[index, 'gold'] = row['classifications']['Commission']
    except:
        print("Can't get commission gold: ", row)
    us_df.loc[index, 'pred'] = row['predictions']['Commission']
# Out:
# Can't get commission gold:  _id                                         5b320fbceb1c822898f01e23
# classifications    {'faretype': 'undefined', 'commission': 'undef...
# country                                                           US
# filename                        2017_ADHOC_NYC-712N010-018FF506.html
# predictions                                     {'Commission': 'no'}
# Name: 0, dtype: object
# Can't get commission gold:  _id                                         5b320fcbeb1c822898f01e5b
# classifications    {'faretype': 'undefined', 'commission': 'undef...
# country                                                           US
# filename           Copy_of_USA_PUB_fare_template_-_20161128_-_SCL...
# predictions                     {'Filed': 'yes', 'Commission': 'no'}
# Name: 1, dtype: object
# Can't get commission gold:  _id                                         5b320fddeb1c822898f01f05
# classifications    {'faretype': 'undefined', 'commission': 'undef...
# ...

# %%
# get all the predicted commission sheet
mask1 = us_df['gold']=='yes'
mask2 = us_df['pred']=='yes'
us_comm = us_df.loc[mask1|mask2]
mask3 = us_df['gold']!='no'
us_comm = us_comm.loc[mask3]
us_comm.drop(['classifications', 'predictions'], axis=1, inplace=True)

# %%
for index, row in us_comm.iterrows():
    text = fs.find_one({'_id': row['_id']}, {'teststring':1})
    us_comm.loc[index, 'teststring'] = text['teststring']

# %%
us_comm
# Out:
#                            _id country  \
# 13    5b321ad4eb1c822898f02fe3      US
# 14    5b321ad4eb1c822898f02fe5      US
# 15    5b321ad8eb1c822898f02ffc      US
# 16    5b321ad8eb1c822898f02ffd      US
# 17    5b321adaeb1c822898f03003      US
# 18    5b321ae2eb1c822898f03026      US
# 19    5b321ae3eb1c822898f0302f      US
# 20    5b321ae8eb1c822898f03047      US
# 21    5b321aeaeb1c822898f0305a      US
# 22    5b321aeceb1c822898f0305d      US
# 23    5b321af5eb1c822898f03064      US
# 24    5b321afaeb1c822898f0306b      US
# 25    5b321afceb1c822898f0307f      US
# 26    5b321b00eb1c822898f0308c      US
# 33    5b321ad3eb1c822898f02fda      US
# 34    5b321ad3eb1c822898f02fdc      US
# 35    5b321ad5eb1c822898f02fe9      US
# 36    5b321ad5eb1c822898f02fea      US
# 37    5b321ad8eb1c822898f02ffa      US
# 38    5b321adceb1c822898f0300b      US
# 39    5b321ae1eb1c822898f0301b      US
# 40    5b321ae2eb1c822898f03024      US
# 41    5b321ae2eb1c822898f03028      US
# ...

# %%
us_comm.iloc[0]
# Out:
# _id                                    5b321ad4eb1c822898f02fe3
# country                                                      US
# filename                   16LAM149-ORIG_Provo_Travel_Ltd_.html
# pred                                                        yes
# gold                                                        NaN
# teststring    BETWEEN PLS/MNL PLS/BKK In the Tour Code Box: ...
# Name: 13, dtype: object

# %%
# feature engineering
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(min_df=3, lowercase=False,
                                   stop_words='english', analyzer='word')
tfidf = tfidf_vectorizer.fit_transform(us_comm['teststring'])
tfidf_feature_list = tfidf_vectorizer.get_feature_names()

# %%
len(tfidf_feature_list)
# Out:
# 7702

# %%
tfidf_feature_list
# Out:
# ['00',
#  '000',
#  '0007',
#  '0011',
#  '003S',
#  '003W',
#  '005H',
#  '007',
#  '008',
#  '00NA',
#  '00Z4',
#  '01',
#  '012',
#  '0121',
#  '0123',
#  '013',
#  '0144',
#  '0150',
#  '01501846',
#  '01538740',
#  '01561884',
#  '0157',
#  '01575781',
#  '0169',
#  '017',
#  '01AUG17',
#  '01Apr17',
#  '01JUN16',
#  '01JUN17',
#  '01Jan',
#  '01Jan2016',
#  '01Jan2018',
#  '01January',
#  '01Mar',
#  '01NOV16',
#  '01Sept',
#  '01jan',
#  '01jan17',
#  '02',
#  '021',
#  '02109',
#  '02116',
#  '02138',
#  '027',
#  '0277',
#  '02HF',
#  '03',
#  '030',
#  '03001',
#  '03063',
#  '032',
#  '0321',
#  '0333',
#  '034',
#  '0350095',
#  '03519294',
#  '03534451',
#  '03547471',
#  '0366',
#  '03745173',
#  '03761376',
#  '03822921',
#  '0391',
#  '03DZ',
#  '04',
#  '040',
#  '04101',
#  '0430',
#  '044',
#  '0442',
#  '0455',
#  '047',
#  '04IA',
#  '04K',
#  '05',
#  '0502',
#  '051',
#  '0517',
#  '052',
#  '0524',
#  '0540',
#  '05446',
#  '05518494',
#  '05519080',
# ...

# %%
from sklearn.cluster import KMeans
km_model = KMeans(n_clusters=2)
km_model.fit(tfidf)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=2, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
tfidf.shape
# Out:
# (319, 7702)

# %%
us_comm['cluster'] = km_model.labels_

# %%
us_comm.to_csv('/Users/chenjialu/Desktop/commission_files.csv')

# %%
us_comm.sort_values(by=['cluster', 'filename'], inplace=True)

# %%
pd.options.display.max_colwidth = 100 
us_comm[['filename', 'cluster']].loc[us_comm['cluster']==1].to_csv('/Users/chenjialu/Desktop/commission_templateA.csv')

# %%
# Out:
#                                               filename  cluster
# 0                 16LAM149-ORIG_Provo_Travel_Ltd_.html        1
# 1    16LAX029-Orig_Stone_Mill_Travel_(01Oct16-30Sep...        1
# 2    16NYC203-Rev1_Carlson_Wagonlit_Travel_SME_Tim....        1
# 4          16NYC914-Rev1_Burekhovich_Travel_Karen.html        1
# 5    17BOS009-Orig.Great_Getaways_Inc.Marius_(JUL17...        1
# 7                         17LAM116-ORIG.Macrotour.html        1
# 8    17LAX528-Rev1_Senator_Travel_(MAR17-FEB19)_Wil...        1
# 14          16DFW004_Orig_Wyndham_Jade_Travel_SHT.html        1
# 15   16DFW502-REV3.API_Virtuoso-added_LAXHKG_biz_cl...        1
# 16      16LAX611_Orig_Santa_Barbara_Travel__Willa.html        1
# 17   16LAX614-Rev1.Cassis_Travel(add_LAXHKG_biz_cla...        1
# 20   16USA888FF500-Rev38_Consolidator_Rates_(hotsen...        1
# 21   17ATL001FF501-orig.Travel_Incorporated._(01May...        1
# 22   17BOS015-Orig_Horizon_Travel_Inc_(MAR17-FEB18)...        1
# ...

# %%
us_comm = pd.read_csv('/Users/chenjialu/Desktop/commission_files.csv')

# %%
# take cluster 0 to further split 
us_comm2 = us_comm.loc[us_comm['cluster']==0]

# %%
# feature engineering
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(min_df=10, lowercase=False,
                                   stop_words='english', analyzer='word')
tfidf = tfidf_vectorizer.fit_transform(us_comm2['teststring'])
tfidf_feature_list = tfidf_vectorizer.get_feature_names()

# %%
len(tfidf_feature_list)
# Out:
# 1980

# %%
tfidf.shape
# Out:
# (127, 1980)

# %%
from sklearn.cluster import KMeans
km_model = KMeans(n_clusters=4)
km_model.fit(tfidf)
clustering = collections.defaultdict(list)
for idx, label in enumerate(km_model.labels_):
        clustering[label].append((us_comm2.iloc[idx]['filename'], us_comm2.iloc[idx]['country']))

# %%
# labels = [3 if i==1 else 0 for i in km_model.labels_]
us_comm2['cluster'] = km_model.labels_
# Out:
# /anaconda3/envs/rassure_nltk/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
us_comm2.sort_values(by=['cluster', 'filename'], inplace =True)
# Out:
# /anaconda3/envs/rassure_nltk/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
us_comm2['template'] = ''
# Out:
# /anaconda3/envs/rassure_nltk/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
# mark incentive agreement as template A
us_comm2.loc[us_comm2['teststring'].str.contains('INCENTIVE AGREEMENT'), 'template'] = 'A'
# Out:
# /anaconda3/envs/rassure_nltk/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
us_comm2[['filename', 'cluster', 'template']].to_csv('/Users/chenjialu/Desktop/other_templates.csv')

# %% [markdown]
# add file path in the check list:

# %%
us_comm = pd.read_csv('/Users/chenjialu/Desktop/CX_Commissions/Predicted Commissions/US/commission_check_US1.csv')

# %%
us_comm['filepath']=''
us_comm['manual check']=''
us_comm['human prediction']=''
us_comm['model prediction']=''

# %%
def create_checklist(us_comm, country):
    new_comm = us_comm.copy()
    # add filepath
    for index, row in us_comm.iterrows():
        us_doc = [doc for doc in fs.find({'filename': row['filename'], 'country': country}, 
                                   {'path':1, 'predictions':1, 'classifications':1} )][0]        
        new_comm.loc[index, 'filepath'] = us_doc['path']
#         try:
#             us_comm.loc[index, 'human prediction'] = us_doc['classifications']['Commission']
#         except:
#             print("no human classification for: ", row['filename'])
        #us_comm.loc[index, 'model prediction'] = us_doc['predictions']['Commission']
    return new_comm
    
# create_checklist(au_comm, 'AU')

# %%
au_comm

# %%
columns = ['filename', 'cluster', 'template', 'filepath', 'human prediction', 'model prediction', 'manual check']
us_comm = us_comm[columns]

# %%
us_comm.to_csv('/Users/chenjialu/Desktop/CX_Commissions/Predicted Commissions/US/commission_check_US1.csv', index=False)

# %% [markdown]
# ### Indentify different templates of CA commission sheet

# %%
def get_market_comm(db, faresheet, country):
    us_docs = [doc for doc in db[faresheet].find({'country': country}, 
                                  {'predictions':1, 'classifications':1, 'path':1, 'teststring':1, 'filename':1, 'country':1})]
    us_df = pd.DataFrame(us_docs)
    us_df['gold'] = ''
    # labelling
    for index, row in us_df.iterrows():
        try:
            us_df.loc[index, 'gold'] = row['classifications']['Commission']
        except:
            print("Can't get commission gold: ", row['filename'])
        us_df.loc[index, 'pred'] = row['predictions']['Commission']
        
    # get all the predicted/classified commission sheet
    mask1 = us_df['gold']=='yes'
    mask2 = us_df['pred']=='yes'
    us_comm = us_df.loc[mask1|mask2]
    mask3 = us_df['gold']!='no'
    us_comm = us_comm.loc[mask3]
    us_comm.drop(['classifications', 'predictions'], axis=1, inplace=True)
    
    return us_comm

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
def tfidf_cluster(us_comm, k=2, v_min_df=2):
    tfidf_vectorizer = TfidfVectorizer(min_df=v_min_df, lowercase=False,
                                   stop_words='english', analyzer='word')
    tfidf = tfidf_vectorizer.fit_transform(us_comm['teststring'])
    tfidf_feature_list = tfidf_vectorizer.get_feature_names()
    print("Number of features: ", len(tfidf_feature_list))
    km_model = KMeans(n_clusters=k)
    km_model.fit(tfidf)
    us_comm['cluster'] = km_model.labels_
    us_comm.sort_values(['cluster', 'filename'], inplace=True)
    return us_comm

# %%
ca_comm = get_market_comm(db, faresheet, 'CA')
# Out:
# Can't get commission gold:  CACOTRCFF600 R0-17 Coast Trading Company wef 01-31Jan17 dep 01Jan-31Mar17.html
# Can't get commission gold:  CAHATCHFF600 R0-17 Hatch Ltd wef 01Sep17-31Aug19_secret.html
# Can't get commission gold:  CAHUOIOFF600 R0-17 Husky Oil Operations Ltd eff 01Jan-31Dec17.html
# Can't get commission gold:  CASEASPFF600 R0-17 Seaspan (Corporate Traveller) wef 20Mar17-31Jan18.html
# Can't get commission gold:  CASIEWIFF600 R1-16 Sierra Wireless add ICN eff 01Nov16-31Oct17.html
# Can't get commission gold:  CAFOSEHFF600 R0-16 Four Seasons Hotels (Travel Trust) wef 01-30Nov16 dep 01Nov-31Dec16.html
# Can't get commission gold:  CALEOPAFF600 R0-17 Leo Paper Inc wef 01-31Jan17 dep 01Jan-31Mar17.html
# Can't get commission gold:  CASEASPFF600 R0-17 Seaspan (GMT) wef 01Feb17-31Jan18.html
# Can't get commission gold:  CATHALEFF600 R2-17 Thales wef 01Dec17-30Sep19_secret.html
# Can't get commission gold:  CAWAMASFF600 R3-16 Wal Mart wef 01Nov16-30Jun18_secret.html
# ...

# %%
len(ca_comm)
# Out:
# 67

# %%
ca_comm
# Out:
#                           _id country  \
# 5    5b2b5bd4eb1c8206a8cda660      CA
# 6    5b2b5bd5eb1c8206a8cda675      CA
# 11   5b2b5bd4eb1c8206a8cda65a      CA
# 12   5b2b5bd4eb1c8206a8cda65d      CA
# 13   5b2b5bd5eb1c8206a8cda67b      CA
# 18   5b2b5bd6eb1c8206a8cda69a      CA
# 19   5b2b5bd7eb1c8206a8cda6aa      CA
# 21   5b2b5bd4eb1c8206a8cda65e      CA
# 23   5b2b5bd5eb1c8206a8cda67c      CA
# 24   5b2b5bd6eb1c8206a8cda699      CA
# 25   5b2b5bd6eb1c8206a8cda69b      CA
# 27   5b2b5bd8eb1c8206a8cda6ad      CA
# 31   5b2b5bd4eb1c8206a8cda661      CA
# 34   5b2b5bd6eb1c8206a8cda69f      CA
# 37   5b2b5bd7eb1c8206a8cda6a8      CA
# 47   5b2b5bd6eb1c8206a8cda69c      CA
# 53   5b2b5bd8eb1c8206a8cda6ac      CA
# 62   5b2b5bd8eb1c8206a8cda6af      CA
# 63   5b2b5bd9eb1c8206a8cda6b2      CA
# 64   5b2b5bd5eb1c8206a8cda66e      CA
# 65   5b2b5bd5eb1c8206a8cda66f      CA
# 67   5b2b5bd6eb1c8206a8cda69e      CA
# 68   5b2b5bd7eb1c8206a8cda6a9      CA
# ...

# %%
ca_comm[['filename', 'cluster']].to_csv('/Users/chenjialu/Desktop/commission_check.csv')

# %%
ca_comm = tfidf_cluster(ca_comm)
# Out:
# Number of features:  5536

# %%
ca_comm['template'] = ''

# %%
ca_comm.loc[ca_comm['teststring'].str.contains('INCENTIVE AGREEMENT'), 'template'] = 'A'
ca_comm.loc[ca_comm['teststring'].str.contains('TICKETING AGREEMENT'), 'template'] = 'A'

# %%
ca_comm.loc[ca_comm['teststring'].str.contains('Tour Wholesaler') , 'template'] = 'B'

# %%
ca_comm.loc[ca_comm['teststring'].str.contains('Half round-trip') , 'template'] = 'B'

# %%
ca_comm.loc[ca_comm['teststring'].str.contains('Special Premium Economy & Economy Class'),  'template'] = 'C'

# %%
ca_comm.loc[ca_comm['teststring'].str.contains('SPECIAL PREMIUM ECONOMY and ECONOMY CLASS COMMISSION')] #,  'template'] = 'C'
# Out:
#                           _id country  \
# 75   5b2b5bd6eb1c8206a8cda698      CA
# 24   5b2b5bd6eb1c8206a8cda699      CA
# 18   5b2b5bd6eb1c8206a8cda69a      CA
# 25   5b2b5bd6eb1c8206a8cda69b      CA
# 47   5b2b5bd6eb1c8206a8cda69c      CA
# 123  5b2b5bd6eb1c8206a8cda69d      CA
# 67   5b2b5bd6eb1c8206a8cda69e      CA
# 34   5b2b5bd6eb1c8206a8cda69f      CA
# 95   5b2b5bd6eb1c8206a8cda6a0      CA
#
#                                                                                                 filename  \
# 75                      WCDA109FF501 R0-16 Special comm to  Sopac-SAfrica WEF 01JAN-30JUN16 DEP ....html
# 24   WCDA109FF591 R0-17 Special comm to  Sopac-SAfrica wef 26Jan-30Jun17 dep 26Jan-24May,15Aug-30Nov,...
# 18                      WCDA109FF591 R1-16 Special comm to  Sopac-SAfrica WEF 17JUN-30SEP16 DEP ....html
# 25   WCDA109FF591 R1-17 Special comm to  Sopac-SAfrica WEF 01MAR-30JUN17 DEP 01MAR17-24MAY17,15AUG201...
# ...

# %%
# ca_comm.loc[ca_comm['teststring'].str.contains('at-source-commission')] #, 'template'] = 'C'
ca_comm.loc[ca_comm['filename'].str.contains('DISTRIBUTION_LIST'), 'template'] = 'C'

# %%
ca_comm[['filename', 'cluster', 'template']].to_csv('/Users/chenjialu/Desktop/commission_check2.csv')

# %%
ca_comm_template = pd.read_csv('/Users/chenjialu/Desktop/commission_check2.csv')

# %%
ca_comm_template
# Out:
#     Unnamed: 0  \
# 0          179
# 1          134
# 2          404
# 3          331
# 4          444
# 5          196
# 6          233
# 7          283
# 8          272
# 9          391
# 10         237
# 11         470
# 12         371
# 13         372
# 14         318
# 15         473
# 16         303
# 17         454
# 18         210
# 19         222
# 20         378
# 21         304
# 22         455
# 23         477
# 24         361
# 25         262
# 26         402
# 27         292
# 28          37
# 29          68
# 30          19
# 31          96
# 32          53
# 33          27
# 34          87
# 35          62
# 36          76
# 37         124
# 38          69
# 39         105
# 40          11
# 41         126
# 42          70
# 43          12
# 44          21
# 45         100
# 46           5
# 47          31
# 48          63
# 49         252
# 50         101
# 51          64
# 52          65
# 53           6
# 54         121
# 55          13
# 56          23
# ...

# %%
ca_comm_cluster = tfidf_cluster(ca_comm, k=5)[['filename', 'cluster']]
# Out:
# Number of features:  5536

# %%
for index, row in ca_comm_cluster.iterrows():
    mask = ca_comm['filename'] == row['filename']
    ca_comm.loc[index, 'cluster'] = row['cluster']

# %%
ca_comm['cluster']=''
ca_comm['template']=''

# %%
for index, row in ca_comm_template.iterrows():
    mask = ca_comm['filename'] == row['filename']
    ca_comm.loc[mask, 'template'] = row['template']

# %%
ca_comm.sort_values(by=['template', 'cluster'], inplace=True)

# %%
ca_comm[['filename','gold', 'pred', 'cluster', 'template']].to_csv('/Users/chenjialu/Desktop/commission_check3.csv')

# %%
ca_comm2[['filename', 'cluster']].to_csv('/Users/chenjialu/Desktop/commission_check2_cluster.csv')

# %% [markdown]
# ### Add filepath in commission

# %%
ca_comm = pd.read_csv('/Users/chenjialu/Desktop/commission_check3.csv')

# %%
ca_comm.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
ca_comm['filepath'] = ''

# %%
for index, row in ca_comm.iterrows():
    path = [doc for doc in fs.find({'filename': row['filename'], 'country': 'CA'}, {'path':1})][0]['path']
    print(path)
    ca_comm.loc[index, 'filepath'] = path
# Out:
# Z:\2017\CA\17NYC104-Rev4.Frosch Travel.added LAXHKG D I class discount.Dan (JAN17-D....docx
# Z:\2017\CA\17NYC203-Rev2.Carlson Wagonlit Travel.SME.Richard (JAN17-DEC17).docx
# Z:\2017\CA\15CHI502-Rev3 Ensemble Travel (NOV15-OCT17) Meredith.docx
# Z:\2017\CA\17NYC203-Rev1.Carlson Wagonlit Travel.SME.Richard (JAN17-DEC17).docx
# Z:\2017\CA\17USA888FF500-Rev8.Consolidator Rates(hotsent20Mar17).docx
# Z:\2017\CA\17NYC015-Orig.NYCYVR contract steph.doc
# Z:\2017\CA\17USA888FF500-Rev9.Consolidator Rates(hotsent13Apr17).docx
# Z:\2017\CA\17USA888FF500-Rev7.Consolidator Rates(hotsent20Feb17).docx
# Z:\2017\CA\17NYC203-Orig Carlson Wagonlit Travel SME Richard.docx
# Z:\2017\CA\18NYC104-Orig.Frosch Travel (JAN18-DEC18) Dan.docx
# Z:\2017\CA\CAN38FF800 R3-17 CX TOUR OPS (Add S class) WEF 06APR17-31MAR18.xlsx
# Z:\2017\CA\WCDA33FF800 R0-18 Tour Ops fare for Scenic Cruises-Omega Travel wef 01De....xlsx
# ...

# %%
ca_comm[['filename', 'filepath', 'human prediction', 'model prediction', 'cluster',
       'template', 'manual check']].to_csv('/Users/chenjialu/Desktop/commission_CA.csv')

# %%
ca_comm[['filename', 'filepath', 'human prediction', 'model prediction', 'cluster',
       'template', 'manual check']]
# Out:
#                                                                                                filename  \
# 0                      17NYC104-Rev4.Frosch_Travel.added_LAXHKG_D_I_class_discount.Dan_(JAN17-D....html
# 1                                  17NYC203-Rev2.Carlson_Wagonlit_Travel.SME.Richard_(JAN17-DEC17).html
# 2                                             15CHI502-Rev3_Ensemble_Travel_(NOV15-OCT17)_Meredith.html
# 3                                  17NYC203-Rev1.Carlson_Wagonlit_Travel.SME.Richard_(JAN17-DEC17).html
# 4                                            17USA888FF500-Rev8.Consolidator_Rates(hotsent20Mar17).html
# 5                                                              17NYC015-Orig.NYCYVR_contract_steph.html
# 6                                            17USA888FF500-Rev9.Consolidator_Rates(hotsent13Apr17).html
# 7                                            17USA888FF500-Rev7.Consolidator_Rates(hotsent20Feb17).html
# ...

# %% [markdown]
# ### Indentify different templates of AU commission sheet

# %%
au_comm = get_market_comm(db, faresheet, 'AU')
# Out:
# Can't get commission gold:  BCODEAUAERREZ_CTA_QLD_AERORESCUE_1603_2016_WEF 01MAR16-28FEB17_secret.html
# Can't get commission gold:  BCODEAUCARAUZ_CTA_QLD_CAREERS AUSTRALIA CTA 1602 SIGNED_WEF 01MAR16-28FEB17_secret.html
# Can't get commission gold:  BCODEAUFLIUNZ_Flinders University 2017-2018 signed CTA_WEF 01AUG17-31JUL18_secret.html
# Can't get commission gold:  BCODEAUGLENCZ_Glencore Contract Schedule 2017 - 19_WEF 01JUL17-30JUN19_secret.html
# Can't get commission gold:  BCODEAUHATCHZ_CTA_QLD_HATCH_Schedule 5 1609_2016_WEF 01SEP16-31AUG17_secret.html
# Can't get commission gold:  BCODEAUINAUH_CTA_WA_Intertek Aust SFA Corp Travel Agreement_WEF 01MAR16-28FEB17_secret.html
# Can't get commission gold:  BCODEAUNEOME_CTA_WA_Neometals_2018 - signed_WEF 01JAN18-31DEC18_secret.html
# Can't get commission gold:  BCODEAUSOLAUZ_Solenis CTA Schedule of discounts_WEF 01MAY17-30APR18_A_secret.html
# ...

# %%
from sklearn.metrics import silhouette_score
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
def choose_k(dat_comm, k1=2, k2=11, v_min_df=2):
    """A function to choose k with tfidf, A higher Silhouette Coefficient indicates that the object is well matched to 
    its own cluster and poorly matched to neighboring clusters."""
    tfidf_vectorizer = TfidfVectorizer(min_df=v_min_df, lowercase=False,
                                   stop_words='english', analyzer='word')
    tfidf = tfidf_vectorizer.fit_transform(dat_comm['teststring'])
    tfidf_feature_list = tfidf_vectorizer.get_feature_names()
    print("Number of features: ", len(tfidf_feature_list))
    for n_cluster in range(k1, k2):
        kmeans = KMeans(n_clusters=n_cluster).fit(tfidf)
        label = kmeans.labels_
        sil_coeff = silhouette_score(tfidf, label, metric='euclidean')
        print("For n_clusters={}, The Silhouette Coefficient is {}".format(n_cluster, sil_coeff))

# %%
choose_k(au_comm, k1=2, k2=11)
# Out:
# For n_clusters=2, The Silhouette Coefficient is 0.23112426698068705
# For n_clusters=3, The Silhouette Coefficient is 0.29596004749029525
# For n_clusters=4, The Silhouette Coefficient is 0.3724921312595539
# For n_clusters=5, The Silhouette Coefficient is 0.41668737293181946
# For n_clusters=6, The Silhouette Coefficient is 0.439138467665263
# For n_clusters=7, The Silhouette Coefficient is 0.4414426669546555
# For n_clusters=8, The Silhouette Coefficient is 0.45888299898212986
# For n_clusters=9, The Silhouette Coefficient is 0.4493116929795296
# For n_clusters=10, The Silhouette Coefficient is 0.4604228578796111

# %% [markdown]
# ### choose 7 as k

# %%
au_comm_cluster=tfidf_cluster(au_comm, k=7, v_min_df=2)
# Out:
# Number of features:  1590

# %%
au_comm_cluster.columns
# Out:
# Index(['_id', 'country', 'filename', 'teststring', 'pred', 'gold', 'cluster'], dtype='object')

# %%
au_comm_cluster[['filename', 'pred', 'gold', 'cluster']].to_csv('/Users/chenjialu/Desktop/commission_check.csv', index=False)

# %% [markdown]
# ### create checklist

# %%
au_comm = pd.read_csv('/Users/chenjialu/Desktop/commission_check.csv')

# %%
au_comm=create_checklist(au_comm, 'AU')

# %%
def create_checklist(us_comm, country):
    new_comm = us_comm.copy()
    # add filepath
    for index, row in us_comm.iterrows():
        us_doc = [doc for doc in fs.find({'filename': row['filename'], 'country': country}, 
                                   {'path':1, 'predictions':1, 'classifications':1} )][0]        
        new_comm.loc[index, 'filepath'] = us_doc['path']
#         try:
#             us_comm.loc[index, 'human prediction'] = us_doc['classifications']['Commission']
#         except:
#             print("no human classification for: ", row['filename'])
        #us_comm.loc[index, 'model prediction'] = us_doc['predictions']['Commission']
    return new_comm
    
au_comm=create_checklist(au_comm, 'AU')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-e6a7613ce62b> in <module>()
#      13     return new_comm
#      14
# ---> 15 au_comm=create_checklist(au_comm, 'AU')
#
# NameError: name 'au_comm' is not defined

# %%
au_comm.to_csv('/Users/chenjialu/Desktop/commission_check.csv', index=False)

# %% [markdown]
# ### NZ market

# %%
nz_comm = get_market_comm(db, faresheet, 'NZ')
# Out:
# Can't get commission gold:  NZ_CORP_R3_2017_MasterList_Feb28.html
# Can't get commission gold:  17AKL249 - 322FF706_SECRET.html
# Can't get commission gold:  17NZ561-575FF506_SECRET.html
# Can't get commission gold:  17NZ003-011FF506(9-13JAN17)_SECRET.html
# Can't get commission gold:  NZ7104_R1_TA17-104_UkEurViaAust_Jan31_2017_REV_WEF_01FEB17-27FEB17_DEP_01FEB17-30NOV17.html
# Can't get commission gold:  NZ7107_R1_TA17-107_UkEurSHOWSTOP_OIcl_Feb24_2017_REV_WEF_24FEB17-27FEB17_DEP_01MAR-30NOV17.html
# Can't get commission gold:  NZ7115_R1_TA17-115_UkEurDscy(std)_Apr24_2017_WEF_16MAY17-30APR18_DEP_16MAY17-30APR19.html
# Can't get commission gold:  NZ7120_R1_TA17-120_EBUkEur_Ph10_Jun29_2017_REV_WEF_01JUL-07SEP17_DEP_01JUL17-28FEB18.html
# Can't get commission gold:  NZ7122R_R1_TA17-122_EBUkEur2018Ph1_Sep08_2017_REV_WEF_10SEP-25SEP17_DEP_16JAN-31AUG18.html
# Can't get commission gold:  NZ7123R_R3_TA17-123_UkEur_Ph11_Sep27_2017_REV_WEF_01SEP17-15NOV17_DEP_01SEP17-15JAN18.html
# ...

# %%
choose_k(nz_comm, k1=2, k2=10)
# Out:
# For n_clusters=2, The Silhouette Coefficient is 0.4538953197427514
# For n_clusters=3, The Silhouette Coefficient is 0.44097637723692046
# For n_clusters=4, The Silhouette Coefficient is 0.4745091049347023
# For n_clusters=5, The Silhouette Coefficient is 0.5151229959523871
# For n_clusters=6, The Silhouette Coefficient is 0.5409860794471184
# For n_clusters=7, The Silhouette Coefficient is 0.5656425679343441
# For n_clusters=8, The Silhouette Coefficient is 0.5840518082361282
# For n_clusters=9, The Silhouette Coefficient is 0.5657587513455863

# %% [markdown]
# choose k as 4

# %%
nz_comm=tfidf_cluster(nz_comm, k=4, v_min_df=3)
# Out:
# Number of features:  1134

# %%
nz_comm[['filename', 'pred', 'gold', 'cluster', 'path']].to_csv('/Users/chenjialu/Desktop/commission_check.csv', index=False)

# %% [markdown]
# ### TH market

# %%
th_comm = get_market_comm(db, faresheet, 'TH')
# Out:
# Can't get commission gold:  THA1250_THA1546-1547_THA1551-1553_THA1555FF530_R10_(GROSS)_TH_Student_Faresheet_s01NOV17-31MAY18_t01NOV17-30SEP18_add_EDI_(upd12Oct17).html
# Can't get commission gold:  THA1524_THA1543FF500_R4A_(GROSS)_y17_TH_PAB_PG_CodeJoint_s01Jun-31Dec17_T-ext30Sep18_(upd27Jul17).html
# Can't get commission gold:  THA1556FF500_R1_FARESHEET_CX+OM__P.3_wef12Jul17-31Dec17.html
# Can't get commission gold:  THA9087FF508_R1B_CUG_King_Power_O_cls_THKPHKG_Faresheet_HKG_IBE_wef01MAR17-30nov17.html
# Can't get commission gold:  THA9100FF708_R1_KOR_GV8_s_09Jun-31Jul17_t_09Jun-30Sep17.html
# Can't get commission gold:  THA9113FF505_R1_KBANK_GV2_JAPAN_s01JUL17-31AUG17_t01Jul17-26Dec17.html
# Can't get commission gold:  THA9118_9120FF509_THA9119_9121FF909_R1_CX_Winter_promotion_s01Sep-30Nov17_t01Sep-28Dec17_(upd04Aug17).html
# Can't get commission gold:  THA1000_THA1001_THA1527-1531_THA1550_THA1556FF500_R10A_(GROSS)_TH_Pab_s01Nov17-31Mar18_t01Nov17-30Sep18_(upd16Oct17).html
# ...

# %%
choose_k(th_comm, k1=2, k2=10)
# choose 6
# Out:
# For n_clusters=2, The Silhouette Coefficient is 0.44973188934967984
# For n_clusters=3, The Silhouette Coefficient is 0.5015560326517737
# For n_clusters=4, The Silhouette Coefficient is 0.5839917914012868
# For n_clusters=5, The Silhouette Coefficient is 0.6189010640480525
# For n_clusters=6, The Silhouette Coefficient is 0.6936799302076326
# For n_clusters=7, The Silhouette Coefficient is 0.7953705136817785
# For n_clusters=8, The Silhouette Coefficient is 0.8018445751380434
# For n_clusters=9, The Silhouette Coefficient is 0.757814486499178

# %%
th_comm=tfidf_cluster(th_comm, k=6, v_min_df=4)
# Out:
# Number of features:  2662

# %%
check_cols = ['filename', 'pred', 'gold', 'cluster', 'path']
th_comm[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check.csv', index=False)
th_comm
# Out:
#                           _id country  \
# 130  5b3207eaeb1c822898efec2b      TH
# 131  5b3207fceb1c822898efec74      TH
# 223  5b3207dfeb1c822898efebec      TH
# 1    5b3207e0eb1c822898efebf4      TH
# 343  5b3207e2eb1c822898efebfc      TH
# 296  5b3207e3eb1c822898efec05      TH
# 129  5b3207e4eb1c822898efec0d      TH
# 222  5b3207cfeb1c822898efeb90      TH
# 272  5b3207d1eb1c822898efeb9d      TH
# 201  5b3207d3eb1c822898efebaa      TH
# 247  5b3207daeb1c822898efebcf      TH
# 295  5b3207dceb1c822898efebdc      TH
# 249  5b320802eb1c822898efece3      TH
# 179  5b320802eb1c822898efece6      TH
# 256  5b32080beb1c822898efee12      TH
# 111  5b32080beb1c822898efee15      TH
# 200  5b3207b8eb1c822898efeaf6      TH
# 38   5b3207c5eb1c822898efeb4f      TH
# 176  5b3207d4eb1c822898efebb2      TH
# 0    5b3207d6eb1c822898efebba      TH
# 101  5b3207d8eb1c822898efebc2      TH
# 155  5b3207deeb1c822898efebe4      TH
# 317  5b320810eb1c822898efee49      TH
# ...

# %% [markdown]
# ### LK market

# %%
lk_comm = get_market_comm(db, faresheet, 'LK')
# Out:
# Can't get commission gold:  2017_CMB_PAB_R03_LKPAB-2017-Rev3_WEF_01FEB-31DEC17_upd_19JAN17_secret.html
# Can't get commission gold:  2017 CMB PAB_R02_LKPAB-2017-Rev2_WEF 27JAN-31DEC17_upd 19JAN17_secret.html
# Can't get commission gold:  7HQCMB207-225FF506.html
# Can't get commission gold:  CMB1169FF501_Australia_Specialist_Fares_-_July_17_SALE_01JUL-30SEP17_DEP_29OCT17-30APR18_secret.html
# Can't get commission gold:  CMB1169FF588_Japan_Specialist_Fares_-NOV-DEC_SALE_17NOV-31DEC17_DEP_17NOV17-31MAR18.html
# Can't get commission gold:  CMBCORP6FF600_BCODELKDAGRP_Daya Group of Companies Corporate Agreement CUTS 2017_WEF 01JAN-31DEC17_PG10.html
# Can't get commission gold:  CMBCORPFF600_BCODELKCHNAA_CACTIC_WEF 01FEB17-31JAN18_Page 04.html
# Can't get commission gold:  CMBCORPFF600_BCODELKCHNAA_CACTIC_WEF 01FEB17-31JAN18_Page 9.html
# Can't get commission gold:  CMBCORPFF600_BCODELKCROCO_CROWN COLOUR CUTS 2017_WEF 01APR17-31MAR18_pg6.html
# ...

# %%
len(lk_comm)
# Out:
# 72

# %%
choose_k(lk_comm, k1=2, k2=10)
#choose k=4
# Out:
# For n_clusters=2, The Silhouette Coefficient is 0.5001373950166155
# For n_clusters=3, The Silhouette Coefficient is 0.44513522268287276
# For n_clusters=4, The Silhouette Coefficient is 0.517768786165211
# For n_clusters=5, The Silhouette Coefficient is 0.49254475600399583
# For n_clusters=6, The Silhouette Coefficient is 0.48847164760186285
# For n_clusters=7, The Silhouette Coefficient is 0.4765234446255341
# For n_clusters=8, The Silhouette Coefficient is 0.4284995714035697
# For n_clusters=9, The Silhouette Coefficient is 0.46680669280034987

# %%
lk_comm_c=tfidf_cluster(lk_comm, k=2, v_min_df=2)
# Out:
# Number of features:  1145

# %%
lk_comm_c[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check.csv', index=False)
lk_comm_c
# Out:
#                           _id country  \
# 18   5b31e9abeb1c822898efb08b      LK
# 127  5b31e9abeb1c822898efb08c      LK
# 139  5b31e9abeb1c822898efb095      LK
# 141  5b31e9aceb1c822898efb0a3      LK
# 169  5b31e9aceb1c822898efb0ac      LK
# 219  5b31e9aceb1c822898efb0ad      LK
# 19   5b31e9adeb1c822898efb0b7      LK
# 7    5b31e9adeb1c822898efb0b8      LK
# 58   5b31e9aeeb1c822898efb0d0      LK
# 203  5b31e9aeeb1c822898efb0d8      LK
# 77   5b31e9aeeb1c822898efb0e8      LK
# 10   5b31e9aeeb1c822898efb0e9      LK
# 157  5b31e9aeeb1c822898efb0ec      LK
# 206  5b31e9afeb1c822898efb0f6      LK
# 226  5b31e9afeb1c822898efb0f7      LK
# 162  5b31e9afeb1c822898efb0ff      LK
# 91   5b31e9afeb1c822898efb108      LK
# 147  5b31e9b0eb1c822898efb10a      LK
# 79   5b31e9b0eb1c822898efb10b      LK
# 53   5b31e9aaeb1c822898efb081      LK
# 17   5b31e9aaeb1c822898efb082      LK
# 126  5b31e9abeb1c822898efb087      LK
# 97   5b31e9abeb1c822898efb08d      LK
# ...

# %% [markdown]
# ### ID market

# %%
id_comm = get_market_comm(db, faresheet, 'ID')
# Out:
# Can't get commission gold:  MES8149FF509-EXKUL FIT PROMO 25AUG-18SEP17.html
# Can't get commission gold:  SUB8002_ALL_R01_NI_GV_02FEB17-31JAN18_ISD 01FEB-31MAR17 (03MAR17)_SECRET.html
# Can't get commission gold:  JKT8310 JKT8308_R01_ALL_FIT FARE_NSEI_01FEB17-31JAN18_ISD 01FEB-05MAR17 (13FEB17)_SECRET.html
# Can't get commission gold:  IDO7962FF600 BCODEIDPEMKOZ SUB.html
# Can't get commission gold:  JKT8371 8362_GROUP_R01_ALL_02FEB-30NOV17_BKD 01FEB-31MAR17 (09MAR17)_SECRET.html
# Can't get commission gold:  JKT8812_R01_ALL_QN_25JAN-31MAR17_ISD 25JAN-12FEB17 (03FEB17)_SECRET.html
# Can't get commission gold:  JKT_IDR8920 IDO8921_R02_ALL_FIT FARE_QEIA_06MAR17-31JAN18_ISD 06-12MAR17 (21MAR17)_Extension_SECRET.html
# Can't get commission gold:  SUB8002 SUB8003_ALL_R01_SEI_FIT_02FEB17-31JAN18_ISD 01FEB-31MAR17  (21FEB17).html
# Can't get commission gold:  IDO7957_ALL_IDPEMKO_R01_01NOV16-31JAN18_ISD 01NOV16-31OCT17 (04AUG17)_SECRET.html
# ...

# %%
id_comm
# Out:
#                           _id country  \
# 38   5b31bd7eeb1c822d2c462b3c      ID
# 60   5b31bd7eeb1c822d2c462b65      ID
# 62   5b31bd7eeb1c822d2c462b73      ID
# 71   5b31bd7eeb1c822d2c462b88      ID
# 87   5b31bd7eeb1c822d2c462b87      ID
# 89   5b31bd7feb1c822d2c462bc4      ID
# 90   5b31bd7feb1c822d2c462bc8      ID
# 96   5b31bd7eeb1c822d2c462b62      ID
# 102  5b31bd7feb1c822d2c462bc5      ID
# 110  5b31bd7eeb1c822d2c462b39      ID
# 128  5b31bd7feb1c822d2c462bd1      ID
# 141  5b31bd7feb1c822d2c462bc6      ID
# 148  5b31bd7eeb1c822d2c462b3a      ID
# 153  5b31bd7feb1c822d2c462bcb      ID
# 157  5b31bd7eeb1c822d2c462b3d      ID
# 159  5b31bd7eeb1c822d2c462b64      ID
# 168  5b31bd7eeb1c822d2c462b52      ID
# 189  5b31bd7eeb1c822d2c462b61      ID
# 190  5b31bd7eeb1c822d2c462b67      ID
# 200  5b31bd7feb1c822d2c462bc7      ID
# 223  5b31bd7eeb1c822d2c462b63      ID
# 224  5b31bd7eeb1c822d2c462b66      ID
# 226  5b31bd7eeb1c822d2c462b70      ID
#
# ...

# %%
choose_k(id_comm, k1=2, k2=10)
#choose k=4
# Out:
# For n_clusters=2, The Silhouette Coefficient is 0.38345626710947067
# For n_clusters=3, The Silhouette Coefficient is 0.3435950547614299
# For n_clusters=4, The Silhouette Coefficient is 0.3935790292920905
# For n_clusters=5, The Silhouette Coefficient is 0.301935214058017
# For n_clusters=6, The Silhouette Coefficient is 0.33340872636074637
# For n_clusters=7, The Silhouette Coefficient is 0.33098019034175225
# For n_clusters=8, The Silhouette Coefficient is 0.30846023306380305
# For n_clusters=9, The Silhouette Coefficient is 0.30304200641321705

# %%
id_comm_c=tfidf_cluster(id_comm, k=4, v_min_df=2)
# Out:
# Number of features:  1581

# %%
id_comm_c[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check.csv', index=False)

# %% [markdown]
# ### NP market

# %%
docs = [doc for doc in db[faresheet].find({'country': 'NP'}, 
                                  {'predictions':1, 'classifications':1, 'path':1, 'teststring':1, 'filename':1, 'country':1})]
np_df = pd.DataFrame(docs)

# %%
len(np_df)
# Out:
# 61

# %%
choose_k(np_df, k1=2, k2=21)
# Out:
# For n_clusters=2, The Silhouette Coefficient is 0.1674356541993712
# For n_clusters=3, The Silhouette Coefficient is 0.2404105473943978
# For n_clusters=4, The Silhouette Coefficient is 0.27358169704654184
# For n_clusters=5, The Silhouette Coefficient is 0.33733038932296955
# For n_clusters=6, The Silhouette Coefficient is 0.3760104304816351
# For n_clusters=7, The Silhouette Coefficient is 0.39244953824505013
# For n_clusters=8, The Silhouette Coefficient is 0.4262521702621188
# For n_clusters=9, The Silhouette Coefficient is 0.45580816292020954
# For n_clusters=10, The Silhouette Coefficient is 0.4536229465650971
# For n_clusters=11, The Silhouette Coefficient is 0.468771596542235
# For n_clusters=12, The Silhouette Coefficient is 0.4689022527319724
# For n_clusters=13, The Silhouette Coefficient is 0.46600435670179513
# For n_clusters=14, The Silhouette Coefficient is 0.47719031634648246
# For n_clusters=15, The Silhouette Coefficient is 0.47886489057544424
# ...

# %%
np_cluster=tfidf_cluster(np_df, k=16, v_min_df=2)
# Out:
# Number of features:  2416

# %%
# sample 1 from each cluster
def sample_by_cluster(np_df, k, sample_num):
    """
    sample_num: number of samples per cluster
    """
    df = pd.DataFrame()
    for i in range(k):
        rows = np_df[np_df['cluster'] == i][:sample_num]    
        df = df.append(rows)
    return df
cluster_df = sample_by_cluster(np_df, 16, sample_num=1)

# %%
cluster_df[['filename', 'path', 'cluster']].to_csv('/Users/chenjialu/Desktop/commission_check_NP.csv', index=False)

# %% [markdown]
# ### TW market

# %%
docs = [doc for doc in db[faresheet].find({'country': 'TW'}, 
                                  {'lang':1, 'predictions':1, 'classifications':1, 'path':1, 'teststring':1, 'filename':1, 'country':1})]
tw_df = pd.DataFrame(docs)

# %% [markdown]
# ### english sheets:

# %%
tw_df_en = tw_df[tw_df['lang']=='en']

# %%
choose_k(tw_df_en, k1=20, k2=41, v_min_df=80)

# %%
tw_df_en_cluster=tfidf_cluster(tw_df_en, k=40, v_min_df=70)
# Out:
# Number of features:  1648
# /anaconda3/envs/rassure_nltk/lib/python3.6/site-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/rassure_nltk/lib/python3.6/site-packages/ipykernel/__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
cluster_df = sample_by_cluster(tw_df_en_cluster, 40, sample_num=1)

# %%
cluster_df[['filename', 'path', 'cluster']].to_csv('/Users/chenjialu/Desktop/commission_check_TW.csv', index=False)

# %% [markdown]
# ### NL market

# %%
docs = [doc for doc in db[faresheet].find({'country': 'TW'}, 
                                  {'lang':1, 'predictions':1, 'classifications':1, 'path':1, 'teststring':1, 'filename':1, 'country':1})]
nl_df = pd.DataFrame(docs)

# %%
len(nl_df)
# Out:
# 2637

# %%
nl_df_cluster=tfidf_cluster(nl_df, k=20, v_min_df=70)
# Out:
# Number of features:  1842

# %%
cluster_df = sample_by_cluster(nl_df_cluster, 20, sample_num=1)

# %%
cluster_df['manual check'] = ''
cluster_df[['filename', 'path', 'cluster']].to_csv('/Users/chenjialu/Desktop/commission_check_NL.csv', index=False)

# %% [markdown]
# ### SCAN market

# %%
scan_comm = get_market_comm(db, faresheet, 'SCAN')
# Out:
# Can't get commission gold:  Boomerang_Pass_&_FJ-MH-NF-TN-VA-JQ_&_LWT_pass_CXKA_Addon_&_SE_Asia_Pass_R10_wef_01Oct17-31Oct17_dep_01Oct17-31Dec18.html
# Can't get commission gold:  Scan_Master__PAB_R09(SCAN701_704_SCAN710_SCAN715_OSLCT10_ARNCT10_CPHCT10)WEF_01Dec17-31Mar18_dep_01Dec17-31Dec18.html
# Can't get commission gold:  Smart_Saver2017_R02_wef_10Jan17-31Jan17_dep_10Jan17-30Nov17.html
# Can't get commission gold:  Boomerang_Pass_&_FJ-MH-NF-TN-VA-JQ_&_LWT_pass_CXKA_Addon_&_SE_Asia_Pass_R08_wef_01Aug17-14Sep17_dep_01Aug17-31dec18.html
# Can't get commission gold:  Scan_Master__PAB_R05(SCAN701_704_SCAN710_SCAN715_OSLCT10_ARNCT10_CPHCT10)WEF_20Apr17-31DEC17_dep_20Apr17-31Dec18.html
# Can't get commission gold:  Scan_Master__PAB_R06(SCAN604_SCAN700_SCAN704_SCAN710_SCAN715)WEF_01JAN17-31DEC17_dep_01Jan17-31Dec18.html
# Can't get commission gold:  Smart_Saver2017_R01a_wef_07Jan17-31Jan17_dep_07Jan17-30Nov17.html
# ...

# %%
choose_k(scan_comm, k1=2, k2=21)
# choose 6
# Out:
# Number of features:  4548
# For n_clusters=2, The Silhouette Coefficient is 0.4321175625555526
# For n_clusters=3, The Silhouette Coefficient is 0.585336518218788
# For n_clusters=4, The Silhouette Coefficient is 0.6157822822691054
# For n_clusters=5, The Silhouette Coefficient is 0.6566444483969666
# For n_clusters=6, The Silhouette Coefficient is 0.6737731033418071
# For n_clusters=7, The Silhouette Coefficient is 0.6510189436649059
# For n_clusters=8, The Silhouette Coefficient is 0.6244597490222801
# For n_clusters=9, The Silhouette Coefficient is 0.6273977655374711
# For n_clusters=10, The Silhouette Coefficient is 0.6571051849405094
# For n_clusters=11, The Silhouette Coefficient is 0.684002832661489
# For n_clusters=12, The Silhouette Coefficient is 0.698523922521571
# For n_clusters=13, The Silhouette Coefficient is 0.6312184362787384
# For n_clusters=14, The Silhouette Coefficient is 0.6650597578956352
# For n_clusters=15, The Silhouette Coefficient is 0.6938595392377943
# ...

# %%
scan_df_cluster=tfidf_cluster(scan_comm, k=6, v_min_df=2)
# Out:
# Number of features:  4548

# %%
scan_df_cluster[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check_SCAN.csv', index=False)

# %% [markdown]
# ### IT Market

# %%
it_comm = get_market_comm(db, faresheet, 'IT')
# Out:
# Can't get commission gold:  ITC4FF600 R03 wef 05OCT17-31MAR18 dep 05OCT17-30SEP18 (04DEC17)_secret.html
# Can't get commission gold:  ITC1FF600 R02 wef 05OCT17-31MAR18 dep 05OCT17-30SEP18 (04DEC17)_secret.html
# Can't get commission gold:  ITC5FF600 R02 wef 05OCT17-31MAR18 dep 05OCT17-30SEP18 (04DEC17)_secret.html
# Can't get commission gold:  IT505FF590(ex HKG) R01A eff 26MAY17-30APR18(25MAY17)_secret.html
# Can't get commission gold:  ITC1FF600 R01 wef 05OCT17-31MAR18 dep 05OCT17-30SEP18 (14NOV17).html
# Can't get commission gold:  ITC4FF600 R02 wef 05OCT17-31MAR18 dep 05OCT17-30SEP18 (13NOV17).html
# Can't get commission gold:  ITC5FF600 R01 wef 05OCT17-31MAR18 dep 05OCT17-30SEP18 (14NOV17).html
# Can't get commission gold:  ITC2FF600 R02 wef 05OCT17-31MAR18 dep 05OCT17-30SEP18 (04DEC17)_secret.html
# Can't get commission gold:  ITC3FF600 R01 wef 05OCT17-31MAR18 dep 05OCT17-30SEP18 (13NOV17).html
# ...

# %%
it_comm['cluster'] = ''
it_comm[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check_IT.csv', index=False)

# %% [markdown]
# ### AFRICA market

# %%
AFRICA_comm = get_market_comm(db, faresheet, 'AFRICA')
# Out:
# Can't get commission gold:  FS ZA CORPORATE TIER_SAF7102FF600_wef 20MAR17-31MAR18_170712.html
# Can't get commission gold:  SAF600_R03_WHOLESALER fare_13NOV17-30SEP18_171116.html
# Can't get commission gold:  SAF710_R02_ETHNIC_JPN_WEF_11MAY17-31MAR18_170929.html
# Can't get commission gold:  7AHJNB153FF506_R01_REV28NOV17.html
# Can't get commission gold:  CAF7003_R04_ WEF 15NOV17-31AUG18_171120.html
# Can't get commission gold:  FS ZA CORPORATE TIER_SAF7102FF600_R03_WEF 31JUL17-31AUG18_170802.html
# Can't get commission gold:  FS ZA CORPORATE TIER_SAF7105FF600_R02_WEF 31JUL17-31AUG18_170802.html
# Can't get commission gold:  FS ZA CORPORATE TIER_SAF7105FF600_wef 14JUN17-31AUG18_170712.html
# Can't get commission gold:  FS ZA PUB 2017-18_R03_PUBLISH FARE_31JUL17-31AUG18_170802.html
# Can't get commission gold:  SAF215FF809_R02_HKG,JP,CN,SEA-JNB_01SEP17-30NOV17_170907_SECRET.html
# Can't get commission gold:  ZA ASIA END OF YEAR SALE WDH_GBE_170927.html
# ...

# %%
len(AFRICA_comm)
# Out:
# 57

# %%
choose_k(AFRICA_comm, k1=2, k2=20, v_min_df=5)
# Out:
# Number of features:  3091
# For n_clusters=2, The Silhouette Coefficient is 0.49614463812910525
# For n_clusters=3, The Silhouette Coefficient is 0.5514496519873823
# For n_clusters=4, The Silhouette Coefficient is 0.6146968148746917
# For n_clusters=5, The Silhouette Coefficient is 0.6422109888711336
# For n_clusters=6, The Silhouette Coefficient is 0.6719602825080656
# For n_clusters=7, The Silhouette Coefficient is 0.7141079373400195
# For n_clusters=8, The Silhouette Coefficient is 0.7307276392939531
# For n_clusters=9, The Silhouette Coefficient is 0.7010278556586205
# For n_clusters=10, The Silhouette Coefficient is 0.7099320158391021
# For n_clusters=11, The Silhouette Coefficient is 0.7233898615367611
# For n_clusters=12, The Silhouette Coefficient is 0.7050741458554
# For n_clusters=13, The Silhouette Coefficient is 0.6840803810452434
# For n_clusters=14, The Silhouette Coefficient is 0.6507320409948018
# For n_clusters=15, The Silhouette Coefficient is 0.6520806905502275
# ...

# %%
AFRICA_comm_cluster=tfidf_cluster(AFRICA_comm, k=8, v_min_df=2)
# Out:
# Number of features:  4304

# %%
AFRICA_comm_cluster[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check_AFRICA.csv', index=False)

# %% [markdown]
# ### SEAMEN market

# %%
sm_comm = get_market_comm(db, faresheet, 'SEAMEN')
# Out:
# Can't get commission gold:  SEAMEN_PAB_SC170701A_-4_-_wef16Jul17-31Dec17_dep16Jul17-31Dec18_upd_04Jul17.html
# Can't get commission gold:  SEAMEN_PAB_SC180101A_-_wef01Jan18-30Jun18_dep01Jan18-30Jun19_upd_15Dec17.html
# Can't get commission gold:  SEAMEN PAB SC180101A CX MARINE FARES 2018 wef01Jan18-30Jun18 dep01Jan18-30Jun19 - upd 15Dec17.html
# Can't get commission gold:  SEAMEN_PAB_SCL8102FF631--ADD_ON_wef08Jan16-30Jun17_dep08Jan-30Jun16.html
# Can't get commission gold:  SEAMEN PAB SCL1102, 1202FF631_01JAN17-30Jun18_ISD01JAN-30JUN17_SECRET.html
# Can't get commission gold:  seamen_pab_SC180101A_-_Worldwide_Seaman_fare_change_summary_list_Dec17.html
# Can't get commission gold:  Seamen_V2017_005_SS_01Jan18-30Jun18_For_POS_HK_and_some_selective_travel_agent.html
# Can't get commission gold:  SEAMEN_PAB_SC170701A_-_wef16Jul17-31Dec17_dep16Jul17-31Dec18_upd_21Jun17.html
# Can't get commission gold:  SEAMEN_PAB_SC180101A_-1_wef01Jan18-30Jun18_dep01Jan18-30Jun19_upd_21Dec17.html
# ...

# %%
choose_k(sm_comm, k1=2, k2=10, v_min_df=5)
# Out:
# Number of features:  3210
# For n_clusters=2, The Silhouette Coefficient is 0.5607008999205152
# For n_clusters=3, The Silhouette Coefficient is 0.6711034825853781
# For n_clusters=4, The Silhouette Coefficient is 0.692840116963312
# For n_clusters=5, The Silhouette Coefficient is 0.7362896445152788
# For n_clusters=6, The Silhouette Coefficient is 0.66576782759366
# For n_clusters=7, The Silhouette Coefficient is 0.5533622721871886
# For n_clusters=8, The Silhouette Coefficient is 0.5256390042429359
# For n_clusters=9, The Silhouette Coefficient is 0.48242767453084323

# %%
sm_comm_cluster=tfidf_cluster(sm_comm, k=5, v_min_df=10)
# Out:
# Number of features:  2428

# %%
sm_comm_cluster[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check_SEAMEN.csv', index=False)

# %% [markdown]
# ### FR market

# %%
fr_comm = get_market_comm(db, faresheet, 'FR')
# Out:
# Can't get commission gold:  OZ NZ SP 2017_v11_20Mar17.html
# Can't get commission gold:  TGV AIR avenant 7 augmentation annuelle 2016 Version ENG.html
# Can't get commission gold:  FR7FF510 - VFR 2017 -v10_20APR17 .html
# Can't get commission gold:  TGV AIR amendment 8 TGV AIR Prices 2017 Version ENG.html
# Can't get commission gold:  avenanttarif2012CX.html
# Can't get commission gold:  FIT CXCA TRIANGULAR 2016_05Apr16.html
# Can't get commission gold:  A_train_agreement_introduced_in_France_R01.html
# Can't get commission gold:  APEX2(20Feb17)_eff_01Apr-31Dec17.html
# Can't get commission gold:  FR7FF519(VFR_CHN_BOOSTER_Sep_-_Dec_17)_eff_27Jul17.html
# Can't get commission gold:  EU28FF599(LWT_Pass_2017_v2)_eff_29Sep17.html
# Can't get commission gold:  FR28FF500(LWT_Pass_2016_FR_v2).html
# Can't get commission gold:  FR7xxxFF706(AD_HOC_GIT_S17_W17_YIP)_eff_26Jul16.html
# Can't get commission gold:  EU3FF596(Cruise_PAB_2017-2019)_eff_20170710.html
# ...

# %%
choose_k(fr_comm, k1=2, k2=10, v_min_df=15)
# Out:
# Number of features:  1011
# For n_clusters=2, The Silhouette Coefficient is 0.5795998571321782
# For n_clusters=3, The Silhouette Coefficient is 0.6271609710043807
# For n_clusters=4, The Silhouette Coefficient is 0.6313240366685394
# For n_clusters=5, The Silhouette Coefficient is 0.6320228106177138
# For n_clusters=6, The Silhouette Coefficient is 0.6271023318322407
# For n_clusters=7, The Silhouette Coefficient is 0.6184022399368302
# For n_clusters=8, The Silhouette Coefficient is 0.5895234686064645
# For n_clusters=9, The Silhouette Coefficient is 0.5690839577066419

# %%
fr_comm_cluster = tfidf_cluster(fr_comm, k=4, v_min_df=15)
# Out:
# Number of features:  1011

# %%
fr_comm_cluster[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check_FR.csv', index=False)

# %% [markdown]
# ### BNL market

# %%
bnl_comm = get_market_comm(db, faresheet, 'BNL')
# Out:
# Can't get commission gold:  AMS700AFF600 BCODE NLGTMORz EFF 01JAN17-31DEC17_secret.html
# Can't get commission gold:  AMS700AFF600 BCODE NLINTNEz EFF 01MAR17-28FEB18_sercet.html
# Can't get commission gold:  AMS700AFF600 BCODE NLTIMIMz EFF 01JAN17-31DEC17_secret.html
# Can't get commission gold:  BNL001AFF482_LUX R01 EFF 01MAR17-28FEB18_secret.html
# Can't get commission gold:  AMS700AFF600 BCODE NLIDEFAz EFF 01FEB17-31JAN18_secret.html
# Can't get commission gold:  AMS700AFF600 BCODE NLKOOINz EFF 01FEB17-31JAN18_secret.html
# Can't get commission gold:  Boomerang Pass Wef 17NOV16-31JUL17_secret.html
# Can't get commission gold:  AMS700AFF600 BCODE NLELIALz EFF 01JAN17-31DEC17_secret.html
# Can't get commission gold:  AMS700AFF600 BCODE NLMVECOz EFF 01FEB17-31JAN18_secret.html
# Can't get commission gold:  AMS700AFF600 BCODE NLAUTBIz EFF 01JAN17-31DEC17_secret.html
# Can't get commission gold:  CAN18FFxx_R6-17_Special_Add-ons__wef_01Nov17-28Feb18.html
# ...

# %%
bnl_comm
# Out:
# Empty DataFrame
# Columns: [_id, country, filename, path, teststring, gold, pred]
# Index: []

# %% [markdown]
# ### VN market

# %%
vn_comm = get_market_comm(db, faresheet, 'VN')
# Out:
# Can't get commission gold:  7SGN071.html
# Can't get commission gold:  Addon2017_R01_WS_SA_eff_10Nov17-FUN.html
# Can't get commission gold:  CXPUB_Winter_2017_R1b_eff_01Oct17-31Mar18_dep_till_31Mar19_20170919.html
# Can't get commission gold:  HAN7210FF600_bcodeVNMOFAX_R1_wef_01Apr17-31Mar18_Ministry_of_Foreign_Affairs.html
# Can't get commission gold:  HAN8510FF508_R1_eff_17May-17Jun17_dep_03Jul-30Nov17_CXKA_HAN_promotion_UPD_170516.html
# Can't get commission gold:  SGN7930FF600_bcodeVNECOCA_R1_wef_01Jun17-01Jun18_Account_offer_ECOTEK_UPD30MAY17.html
# Can't get commission gold:  SGN7940FF600_bcodeVNFPTCO_R1_wef_01May17-30Apr18_FPT_-_Evaluation.html
# Can't get commission gold:  SGN8028FF508_R1_eff_05APR-05MAY17_dep_till_20DEC17_One_way_Fare_Promotion_2017_UPD20170330.html
# Can't get commission gold:  SGN8114FF600_bcodeVNGIANE_R1_wef_01Apr17-01Apr18_Account_offer_GIA_ANH_UPD10Apr2017.html
# ...

# %%
choose_k(vn_comm, k1=2, k2=10, v_min_df=10)
# Out:
# Number of features:  2028
# For n_clusters=2, The Silhouette Coefficient is 0.6081380026590161
# For n_clusters=3, The Silhouette Coefficient is 0.35925795068115796
# For n_clusters=4, The Silhouette Coefficient is 0.39363053956029587
# For n_clusters=5, The Silhouette Coefficient is 0.3686078337706319
# For n_clusters=6, The Silhouette Coefficient is 0.3692506232054505
# For n_clusters=7, The Silhouette Coefficient is 0.4346246156956222
# For n_clusters=8, The Silhouette Coefficient is 0.4717999900643367
# For n_clusters=9, The Silhouette Coefficient is 0.502630393662543

# %%
comm_cluster = tfidf_cluster(vn_comm, k=2, v_min_df=15)
# Out:
# Number of features:  1418

# %%
comm_cluster[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check_VN.csv', index=False)

# %% [markdown]
# ### CN market

# %%
comm = get_market_comm(db, faresheet, 'CN')
# Out:
# Can't get commission gold:  CNASIAIFF600_NKG_bcodeCNASIAI_0831105_eff 28Apr-31Oct17_dep 01Jun17-31May18_terminate_secret.html
# Can't get commission gold:  CNASIAIFF600_NKG_bcodeCNASIAI_0831105_eff 28Apr17-31May18_dep from 01Jun17_secret.html
# Can't get commission gold:  CNCARLEFF600_SHA_bcodeCNCARLE_0830774,0830721,0830602_wef 01Oct17-30Sep18_secret.html
# Can't get commission gold:  CNCERI9FF600_BJS_bcodeCNCERI9_0831519,0831872_eff 16Jun17-30Jun18_dep from 01Jul17_secret.html
# Can't get commission gold:  CNDANAXFF600_SHA_bcodeCNDANAX_0830628,0830084_wef 01DEC17-30NOV18_secret.html
# Can't get commission gold:  CNDETONFF600_CTU_bcodeCNDETON_0833329_eff 19Jun17-30Jun18_dep from 01Jul17_secret.html
# Can't get commission gold:  CNEASEPFF600_XMN_bcodeCNEASEP_0832163_eff 23Jun17-30Jun18_dep from 01Jul17_secret.html
# Can't get commission gold:  CNEXIMBFF600_BJS_bcodeCNEXIMB_0830064_eff 07Sep17-30Sep18_dep from 01Oct17_secret.html
# ...

# %%
choose_k(comm, k1=2, k2=5, v_min_df=2)
# Out:
# Number of features:  1200
# For n_clusters=2, The Silhouette Coefficient is 0.6709026024462739
# For n_clusters=3, The Silhouette Coefficient is 0.588741150598186
# For n_clusters=4, The Silhouette Coefficient is 0.7142857142857143

# %%
comm_cluster = tfidf_cluster(comm, k=4, v_min_df=2)
# Out:
# Number of features:  1200

# %%
comm_cluster[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check_CN.csv', index=False)

# %% [markdown]
# ### BE market

# %%
comm = get_market_comm(db, faresheet, 'BE')
# Out:
# Can't get commission gold:  BRU700AFF600 BCODE BEROGIEz EFF 01APR16-31MAR17_secret.html
# Can't get commission gold:  BRU700AFF600 BCODE BEAIBVIz EFF 01JUN17-31MAY18_secret.html
# Can't get commission gold:  BRU700AFF603 BCODE BEALLXXz EFF 01OCT17-30SEP18_secret.html
# Can't get commission gold:  BRU700AFF600 BCODE BEFNGGRz EFF 01JAN17-31DEC17_secret.html
# Can't get commission gold:  BUSINESS CLASS APEX WEF 01MAR17-30APR17 DEP 01MAR17-31DEC17_secret.html
# Can't get commission gold:  BRU700AFF600 BCODE BEDIACEz EFF 01APR17-31MAR18_secret.html
# Can't get commission gold:  BRU700AFF602 BCODE BECORTIz EFF 01OCT17-30SEP18_secret.html
# Can't get commission gold:  BRU700AFF600 BCODE BEBABYLz EFF 01JUN17-31DEC17_secret.html
# Can't get commission gold:  BRU700AFF601 BCODE BEBRUTEz EFF 01OCT17-30SEP18_secret.html
# Can't get commission gold:  BRU700AFF601 BCODE BEEXMARz EFF 01JUL17-30JUN18_secret.html
# Can't get commission gold:  Boomerang Pass Wef 17NOV16-31JUL17_secret.html
# ...

# %%
# choose_k(comm, k1=2, k2=5, v_min_df=2)
comm
# Out:
# Empty DataFrame
# Columns: [_id, country, filename, path, teststring, gold, pred]
# Index: []

# %% [markdown]
# ### KH market

# %%
comm = get_market_comm(db, faresheet, 'KH')
# Out:
# Can't get commission gold:  PNH8078 8079_20170401_Japan_dep_01Jul17 - 30Sep17_isd_01Jul17 - 30Sep17.html
# Can't get commission gold:  PNH8087_20170801_China_dep_01Aug17_-_31Nov17_isd_01Aug17_-_30Sep17.html
# Can't get commission gold:  PNH8088_20170501_China_dep_01May17_-_31Jul17_isd_01May17_-_30Sep17.html
# Can't get commission gold:  PNH8094_20170610_China_dep_15Jun17_-_31Aug17_isd_10Jun17_-_30Jun317.html
# Can't get commission gold:  PNH8081_8082_8083FF508_20170201_China_dep_01Feb17_-_30Jun17_dep_01Feb17_-_30Apr17.html
# Can't get commission gold:  PNH8095_8096_20170715_China_Taiwan_dep_15Jul17_-_31Oct17_isd_15Jul17_-_15Aug17.html
# Can't get commission gold:  PNH8051_8052_8053_20170501_HKG_dep_01May17_-_31Jul17_isd_01May17_-_30Sep17.html
# Can't get commission gold:  PNH8076_8077_8084_8089_20170501_MNL_NEA_dep_01May17_-_31Jul17_isd_01May17_-_30Sep17.html
# Can't get commission gold:  PNH8078_8079_20170928_Japan_dep_01Oct17_-_31Dec17_isd_01Oct17_-_30Dec17.html
# ...

# %%
comm['cluster']=''
comm[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check_KH.csv', index=False)

# %% [markdown]
# ### SG market

# %%
comm = get_market_comm(db, faresheet, 'SG')
# Out:
# Can't get commission gold:  17SIN116-HKG-EY-R01_wef_01-21Nov17_dep_01Nov17-31Oct18.html
# Can't get commission gold:  17SIN122-ALL-EY-PUB_wef_22Nov-31Dec_dep_22Nov17-31Oct18.html
# Can't get commission gold:  Corporate_Parameters_R01a_SIN1711&1712&1713&1714&1715FF600orSINBP30~SINBP50FF600_1JUN17-30AUG18.html
# Can't get commission gold:  SIN8921FF505_R01_wef_15Nov16-31Mar17_dep_15Nov16-30Jun17.html
# Can't get commission gold:  SIN8949FF809_R03__wef_28Mar17-31Dec17_dep_28Mar17-31Mar18_(1).html
# Can't get commission gold:  SIN8976FF505_R01_wef_01Jan17-31Jul17_dep_01Jan17-31dec17.html
# Can't get commission gold:  SIN8988_SIN9044FF505_R02_wef_01Feb17-30Sep17_Dep_01Feb17-31Dec17.html
# Can't get commission gold:  SIN9026FF505_R01_wef_04Apr-25Apr17_dep_04Apr17-31Mar18.html
# Can't get commission gold:  SIN9027FF505_R01_wef_04Apr-25Apr17_dep_04Apr17-31Mar18.html
# Can't get commission gold:  SIN9048FF505_R01_wef_17May-06Jun17_dep_17May17-31May18.html
# ...

# %%
choose_k(comm, k1=2, k2=8, v_min_df=2)
# Out:
# Number of features:  560
# For n_clusters=2, The Silhouette Coefficient is 0.361285099353317
# For n_clusters=3, The Silhouette Coefficient is 0.40485123024474556
# For n_clusters=4, The Silhouette Coefficient is 0.45267797884358785
# For n_clusters=5, The Silhouette Coefficient is 0.4618993247225539
# For n_clusters=6, The Silhouette Coefficient is 0.40839424403486385
# For n_clusters=7, The Silhouette Coefficient is 0.3907805650540992

# %%
comm_cluster = tfidf_cluster(comm, k=5, v_min_df=2)
# comm[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check_SG.csv', index=False)
# Out:
# Number of features:  560

# %%
comm[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check_SG.csv', index=False)

# %% [markdown]
# ### BKI market

# %%
comm = get_market_comm(db, faresheet, 'BKI')
# Out:
# Can't get commission gold:  17BKI096FF506.html
# Can't get commission gold:  17BKI034FF506.html
# Can't get commission gold:  17BKI037FF706.html
# Can't get commission gold:  17BKI111FF506.html
# Can't get commission gold:  BKI1002_20161024_NAM EUR_STU FARE_dep_24Oct16 - 30Sep17.html
# Can't get commission gold:  BKI1006 1007_20161125_World_wef_25Nov16.html
# Can't get commission gold:  17BKI033FF506.html
# Can't get commission gold:  17BKI040FF506.html
# Can't get commission gold:  17BKI056FF506.html
# Can't get commission gold:  BKI1001 1002  2001_20170630_World_dep_01Jul17 - 30Sep18_isd_01Jul17 - 31Dec17.html
# Can't get commission gold:  17BKI044FF506.html
# Can't get commission gold:  17BKI059FF506.html
# Can't get commission gold:  BKI8087_20170120_Europe NAM_dep_30Jan17 - 30Jun17.html
# Can't get commission gold:  BKI8088_20161222_HKG_dep_28Dec16 - 31Jan17.html
# Can't get commission gold:  BKI1001 1002  2001_20161208_World_wef_08Dec16.html
# ...

# %%
comm
#choose_k(comm, k1=2, k2=8, v_min_df=2)
# Out:
# Empty DataFrame
# Columns: [_id, country, filename, path, teststring, gold, pred]
# Index: []

# %% [markdown]
# ### BD market

# %%
comm = get_market_comm(db, faresheet, 'BD')
# Out:
# Can't get commission gold:  CORP Sales.html
# Can't get commission gold:  17BD095-106FF506_17BD096FF706_17BD103FF706.html
# Can't get commission gold:  17BD138_17BD140-141FF506_17BD139FF706_17BD142FF706.html
# Can't get commission gold:  CXBDCNFF509(Promo_to_CN)_eff_28_Sep_17.html
# Can't get commission gold:  CXBDHKFF509(Promo_Offer_for_HKG)_eff_31May17_Original.html
# Can't get commission gold:  CXBDXXFF500(2017)_R03(DAC_PAB)_wef_22Apr'17.html
# Can't get commission gold:  CXBDXXXFF509(Promo_to_NAM_AU_JP_KR_TW)_eff_04May17.html
# Can't get commission gold:  17BD120-127FF506_17BD119-125FF706.html
# Can't get commission gold:  CXBDXXXFF509(Promo_to_NAM_AU_JP_KR_TW)_eff_31_Jul17.html
# Can't get commission gold:  17BD022-032FF506_17BD029FF706.html
# Can't get commission gold:  17BD056-059FF506_17BD055FF706.html
# Can't get commission gold:  CXBDXXFF500(2017)_R05(DAC_PAB)_wef_12Jun17.html
# Can't get commission gold:  CXBDXXXFF509(Promo_to_NAM_AU_JP_KR_TW)_eff_05Jun17.html
# ...

# %%
comm.to_csv('/Users/chenjialu/Desktop/commission_check_BD.csv', index=False)

# %% [markdown]
# ### GUM market

# %%
comm = get_market_comm(db, faresheet, 'GUM')
# Out:
# Can't get commission gold:  2016_GUMCX_General_Fares_R01A_SALE_01MAR-31DEC16_DEP_01MAR16-30JUN17_secret.html
# Can't get commission gold:  2016_GUMCX_General_Fares_R02_SALE_07APR-31DEC16_DEP_07APR16-30JUN17_secret.html
# Can't get commission gold:  2016_GUMCX_General_Fares_R01B_SALE_01MAR-31DEC16_DEP_01MAR16-30JUN17_secret.html
# Can't get commission gold:  2016_GUMCX_General_Fares_R01_SALE_01MAR-31DEC16_DEP_01MAR16-30JUN17_secret.html

# %%
comm
# Out:
# Empty DataFrame
# Columns: [_id, country, filename, path, teststring, gold, pred]
# Index: []

# %% [markdown]
# ### MN market

# %%
comm = get_market_comm(db, faresheet, 'MN')
# Out:
# Can't get commission gold:  ULN5155FF560_R1702_SWP_eff_04JUL17-31MAR18_dep_till_30JUN18_PEY.html
# Can't get commission gold:  ULN5750FF560_R1702_SEA_eff_24AUG17-31MAR18_dep_till_30JUN18.html
# Can't get commission gold:  ULN5850FF560_R1701_NAM_wef_03Feb17-31Mar18_dep__till_30Jun18_secret.html
# Can't get commission gold:  ULN5650FF560_R1701_MEINSA_eff_25Jan17-31Mar18_dep_till_30Jun18.html
# Can't get commission gold:  ULN5650FF560_R1702_MEINSA_eff_25JUL17-31MAR18_dep_till_30JUN18.html
# Can't get commission gold:  ULN5858FF560_R1703_NAM_eff_08Aug17-31Mar18_dep_till_30Jun18_Y+C.html
# Can't get commission gold:  ULN5750FF560_R1603_SEA_eff_25JUN16-31MAR17_dep_till_30JUN17.html
# Can't get commission gold:  ULN5855FF560_R1603_NAM_eff_30JUN16-31MAR17_dep_till_30JUN17_PEY.html
# Can't get commission gold:  ULN5858FF560_R1701_NAM_eff_03Feb17-31Mar18_dep_till_30Jun18_Y+C.html
# Can't get commission gold:  ULN5655FF560_R1701_SA_eff_03Feb17-31Mar18_dep_03Feb17-30Jun18_PEY.html
# ...

# %%
comm
# Out:
# Empty DataFrame
# Columns: [_id, country, filename, path, teststring, gold, pred]
# Index: []

# %% [markdown]
# ### KR market

# %%
comm = get_market_comm(db, faresheet, 'KR')
# Out:
# Can't get commission gold:  17K003FF706_secret.html
# Can't get commission gold:  17K014FF506_secret.html
# Can't get commission gold:  17K085FF506_secret.html
# Can't get commission gold:  17K103FF706_secret.html
# Can't get commission gold:  17K010FF506_secret.html
# Can't get commission gold:  17K005FF506_secret.html
# Can't get commission gold:  17K028FF506_secret.html
# Can't get commission gold:  17K034FF506_secret.html
# Can't get commission gold:  17K013FF506_secret.html
# Can't get commission gold:  17K082FF706_secret.html
# Can't get commission gold:  17K102FF506_secret.html
# Can't get commission gold:  17K007FF506_UD_secret.html
# Can't get commission gold:  17K027FF706_secret.html
# Can't get commission gold:  17K042FF706_secret.html
# Can't get commission gold:  17K087FF506_secret.html
# Can't get commission gold:  17K002FF506_secret.html
# Can't get commission gold:  17K006FF506_secret.html
# Can't get commission gold:  17K023FF506_secret.html
# ...

# %%
choose_k(comm, k1=2, k2=8, v_min_df=2)
# Out:
# Number of features:  760
# For n_clusters=2, The Silhouette Coefficient is 0.8543509524865062
# For n_clusters=3, The Silhouette Coefficient is 0.7233422942765854
# For n_clusters=4, The Silhouette Coefficient is 0.7288045997913615
# For n_clusters=5, The Silhouette Coefficient is 0.6853952355002096
# For n_clusters=6, The Silhouette Coefficient is 0.8073784387203208
# For n_clusters=7, The Silhouette Coefficient is 0.770439892025226

# %%
comm_cluster = tfidf_cluster(comm, k=2, v_min_df=2)
comm[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check_KR.csv', index=False)
# Out:
# Number of features:  760

# %% [markdown]
# ### DE market

# %%
comm = get_market_comm(db, faresheet, 'DE')
# Out:
# Can't get commission gold:  CZ_Economy_PROMO(gross)_R03_wef_06MAY17-06JUL17_dep_06MAY17-30JUN17_&_15AUG17-18DEC17.html
# Can't get commission gold:  FRA605FF531(Stuednt Youth) R01 wef 09JAN17-30APR18 dep 01APR17-30APR18_secret.html
# Can't get commission gold:  AT_Business_Promo_R02_wef_01DEC17-30JAN18_dep_01DEC17-01FEB18.html
# Can't get commission gold:  AT_Economy_Promo_R04_wef_01DEC17-30JAN18_dep_01DEC17-15APR18.html
# Can't get commission gold:  Balkans_PEY_Promo_Sale_R01_wef_14SEP17-15NOV17_dep_25OCT17-15APR18.html
# Can't get commission gold:  PL_Business_Promo(gross)__R01_wef_06MAY17-12JUL17_dep_12MAY17-15SEP17_&_01NOV17-31DEC17.html
# Can't get commission gold:  DE PAB(FRA912,922,923,997,956,942) R02A eff 01APR17-30APR18 upd 12APR17_secret.html
# Can't get commission gold:  PL_Y_&_PEY_Promo(gross)__R02_wef_20SEP17-15NOV17_dep_25OCT17-15APR18.html
# Can't get commission gold:  ZRH01FF790 FF590 ZRH04FF590 R01 wef 01NOV16-30SEP17 dep 01JAN17-30SEP17.html
# ...

# %%
choose_k(comm, k1=2, k2=15, v_min_df=10)
# Out:
# Number of features:  1695
# For n_clusters=2, The Silhouette Coefficient is 0.22930141241524385
# For n_clusters=3, The Silhouette Coefficient is 0.20850815648449952
# For n_clusters=4, The Silhouette Coefficient is 0.2429403494907079
# For n_clusters=5, The Silhouette Coefficient is 0.2893404183201774
# For n_clusters=6, The Silhouette Coefficient is 0.3334366021763724
# For n_clusters=7, The Silhouette Coefficient is 0.34034312768824854
# For n_clusters=8, The Silhouette Coefficient is 0.3647463466890578
# For n_clusters=9, The Silhouette Coefficient is 0.3707021950074117
# For n_clusters=10, The Silhouette Coefficient is 0.39750452478593945
# For n_clusters=11, The Silhouette Coefficient is 0.42979582549606693
# For n_clusters=12, The Silhouette Coefficient is 0.4332582980456367
# For n_clusters=13, The Silhouette Coefficient is 0.47277706530200775
# For n_clusters=14, The Silhouette Coefficient is 0.45887999760796083

# %%
comm_cluster = tfidf_cluster(comm, k=13, v_min_df=10)
comm[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check_DE.csv', index=False)
# Out:
# Number of features:  1695

# %% [markdown]
# ### PH market

# %%
comm = get_market_comm(db, faresheet, 'PH')
# Out:
# Can't get commission gold:  CEB8307FF909_HK_WEF_15-31MAR17_DEP_15-31MAR17_Hong_Kong_Business_Class_50%_Off.html
# Can't get commission gold:  CEB8308_8309FF509_909_R02_WEF_20JAN-03FEB17_DEP_21JAN-31DEC17_CEBCX_Great_BDO_Sale_20-22Jan_proposal_upd_18Jan.html
# Can't get commission gold:  CEB8331FF505_905_WEF_15-31MAY17_DEP_UNTIL_20MAR18_CEBCX_Metrobank_Promo.html
# Can't get commission gold:  CW-IM-ST_R01_WEF_01APR-31DEC17_DEP_01APR17-30JUN18_GGT_MNL_CIS_Faresheet_secret.html
# Can't get commission gold:  CXKA_PH_OAL_ADD_ON_FARES_R01_WEF_05-11JAN17_DEP_05JAN-30JUN17_secret.html
# Can't get commission gold:  CXOM_Codeshare_Published_Fares_WEF_10JUL-31DEC17_DEP_12JUL17-31DEC18.html
# Can't get commission gold:  MNL8082FF618_HKG_R03b_WEF_04JUL-15DEC17_DEP_UNTIL_15DEC17_HKG_CW_Smartsaver.html
# Can't get commission gold:  MNL8133FF509_8263FF909_HKG_R01_WEF_01JAN-28FEB17_DEP_01JAN-31OCT17_HKG_Smartsaver.html
# ...

# %%
choose_k(comm, k1=2, k2=5, v_min_df=10)
# Out:
# Number of features:  1579
# For n_clusters=2, The Silhouette Coefficient is 0.8156092287378999
# For n_clusters=3, The Silhouette Coefficient is 0.4975185080880527
# For n_clusters=4, The Silhouette Coefficient is 0.5518408097784484

# %%
comm_cluster = tfidf_cluster(comm, k=2, v_min_df=10)
comm[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check_PH.csv', index=False)
# Out:
# Number of features:  1579

# %% [markdown]
# ### GB market

# %%
comm = get_market_comm(db, faresheet, 'GB')
# Out:
# Can't get commission gold:  LON2282FF502-HK-CN-ASIA-LWTP3-16 R01 wef 16Dec16-28Feb17 dep 06Jan-31Dec17.html
# Can't get commission gold:  LON4786FF512-VN-CMN-LWTP3-16 R01 wef 16Dec16-28Feb17 dep 06Jan17-06Dec17.html
# Can't get commission gold:  LON4788FF512-PH-CMN-LWTP3-16 R01 wef 16Dec16-28Feb17 dep 06Jan-06Dec17.html
# Can't get commission gold:  LON4789FF512-CN-CMN-LWTP3-16v2 R02 wef 10~28Feb17 dep 06Jan-06Dec17.html
# Can't get commission gold:  LON4811FF501-6F-TAC0617 R02 wef 30Jun-06Aug17 dep 24Aug17-07Jun18.html
# Can't get commission gold:  LON4817FF512-TW-CM-LWT-W17-18 R01 wef 15Dec17-28Feb18 dep 09Jan18-06Dec18.html
# Can't get commission gold:  LON5463FF802-FC-LWTP2-17v2_R02 wef 18Aug17-31Oct17 dep 21Aug17-19Jun18.html
# Can't get commission gold:  LON5467FF802-IT-TF-LWT-W17-18 R01 wef 15Dec17-28Feb18 dep 09Jan18-06Dec18.html
# Can't get commission gold:  LON5500FF800-ITX-2017-19v2 R02 wef 01Jun17-31Mar18 dep 01Jun17-31Mar19.html
# ...

# %%
choose_k(comm, k1=2, k2=20, v_min_df=10)
# Out:
# Number of features:  1324
# For n_clusters=2, The Silhouette Coefficient is 0.17195105697676794
# For n_clusters=3, The Silhouette Coefficient is 0.18447138745628924
# For n_clusters=4, The Silhouette Coefficient is 0.20917699293238903
# For n_clusters=5, The Silhouette Coefficient is 0.2578575801349787
# For n_clusters=6, The Silhouette Coefficient is 0.2710782043081018
# For n_clusters=7, The Silhouette Coefficient is 0.28197789922886224
# For n_clusters=8, The Silhouette Coefficient is 0.30616005694039083
# For n_clusters=9, The Silhouette Coefficient is 0.3252023516889062
# For n_clusters=10, The Silhouette Coefficient is 0.3289122530642709
# For n_clusters=11, The Silhouette Coefficient is 0.35585630918991557
# For n_clusters=12, The Silhouette Coefficient is 0.3787578438809449
# For n_clusters=13, The Silhouette Coefficient is 0.38999445433371355
# For n_clusters=14, The Silhouette Coefficient is 0.4041052847050895
# ...

# %%
len(comm)
# Out:
# 117

# %%
comm_cluster = tfidf_cluster(comm, k=14, v_min_df=10)
comm[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check_GB.csv', index=False)
# Out:
# Number of features:  1324

# %% [markdown]
# ### IN market

# %%
comm = get_market_comm(db, faresheet, 'IN')
# Out:
# Can't get commission gold:  17BM049-054FF506_17BM307-328FF706.html
# Can't get commission gold:  17CU011FF506_17CU001-002FF596.html
# Can't get commission gold:  17CU024FF506_17CU037FF706.html
# Can't get commission gold:  17CU032-064FF506.html
# Can't get commission gold:  17DL036-037FF506_17DL323-328FF706.html
# Can't get commission gold:  BLR_PUB_Tactical_Fares_Asia_&_SWP_Revision_31MAY2017.html
# Can't get commission gold:  BLR_PUB_Tactical_Fares_NAM_OW_Fares_added_02JUN2017.html
# Can't get commission gold:  CCU_Tactical_Fares_Published_Asia-SWP_revision_02NOV2017.html
# Can't get commission gold:  Corporates_with_Value-Adds_01OCT16.html
# Can't get commission gold:  CXCORPFF600(1.0_Paytm_IN_PUB_&_Y-W-J-F-_Fares_New)(INPAYTMZ)29MAY17.html
# Can't get commission gold:  CXCORPFF600(3.0_DELOITTE_IN_PUB_&_Y-W-J-F-_Fares_Revision)(INDESUSZ)_eff_25MAY17.html
# Can't get commission gold:  CXDPTBFFF800(2.0_DEL-HKG_TBF_Revision)_A_eff_01MAY'17.html
# ...

# %%
choose_k(comm, k1=2, k2=10, v_min_df=10)
# Out:
# Number of features:  536
# For n_clusters=2, The Silhouette Coefficient is 0.5539142788588134
# For n_clusters=3, The Silhouette Coefficient is 0.6340366684560913
# For n_clusters=4, The Silhouette Coefficient is 0.7443559924105645
# For n_clusters=5, The Silhouette Coefficient is 0.7777389107224412
# For n_clusters=6, The Silhouette Coefficient is 0.7261239540237715
# For n_clusters=7, The Silhouette Coefficient is 0.6851013041243315
# For n_clusters=8, The Silhouette Coefficient is 0.6995731929298465
# For n_clusters=9, The Silhouette Coefficient is 0.6346945770246797

# %%
comm_cluster = tfidf_cluster(comm, k=5, v_min_df=5)
comm[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check_IN.csv', index=False)
# Out:
# Number of features:  1007

# %% [markdown]
# ### IL market

# %%
comm = get_market_comm(db, faresheet, 'IL')
# Out:
# Can't get commission gold:  IL_PEY_Promo_R04_wef_16APR17-15MAY17_dep_26MAR17-31OCT17.html
# Can't get commission gold:  IL_Economy_Promo(Q_class)_R08_wef_31JUL17-05SEP17_dep_20AUG17-07SEP17.html
# Can't get commission gold:  IL_Economy_Promo(O_class)_R03_wef_02FEB17-15APR17_dep_02MAY17-30JUN17_&_21AUG17-17SEP17.html
# Can't get commission gold:  IL_Economy_Promo(Q_class)_R01_wef_24JAN17-15FEB17_dep_02MAY17-30JUN17_&_21AUG17-17SEP17.html
# Can't get commission gold:  IL_Economy_Promo(Q_class)_R09_wef_15SEP17-31OCT17_dep_16NOV17-15MAR18.html
# Can't get commission gold:  IL_Economy_Promo(Q_class)_R11_wef_27OCT17-30NOV17_dep_16NOV17-15MAR18.html
# Can't get commission gold:  TLV444FF444_R01_wef_03SEP17-18SEP17_dep_18SEP17-23OCT17.html
# Can't get commission gold:  TLV555FF555_R01_wef_10AUG17-04SEP17_dep_18SEP17-23OCT17.html
# Can't get commission gold:  IL_Economy_Promo(Q_class)_R02_wef_02FEB17-15MAR17_dep_02MAY17-17SEP17.html
# ...

# %%
# choose_k(comm, k1=2, k2=10, v_min_df=10)
comm
# Out:
# Empty DataFrame
# Columns: [_id, country, filename, path, teststring, gold, pred]
# Index: []

# %% [markdown]
# ### JP market

# %%
comm = get_market_comm(db, faresheet, 'JP')
# Out:
# Can't get commission gold:  7AHT021_170918_SECRET.html
# Can't get commission gold:  B-CODE JPFUJEL R02_01APR17-30SEP17_171114_SECRET.html
# Can't get commission gold:  B-CODE JPMHPS R01_01OCT16-31MAR17_161222_secret.html
# Can't get commission gold:  B-CODE JPMIELT R02_01APR17-31MAR18_171114_SECRET.html
# Can't get commission gold:  B-CODE JPSUMI R01_01APR16-31MAR17_160817_secret.html
# Can't get commission gold:  7AHT011_170328.html
# Can't get commission gold:  7AHS012_170510_secret.html
# Can't get commission gold:  7AHS019_171115_secret.html
# Can't get commission gold:  8AHT001_171211_secret.html
# Can't get commission gold:  7AHC003_170801_SECRET.html
# Can't get commission gold:  B-CODE JPMITT R01_01APR16-31MAR17_160817_secret.html
# Can't get commission gold:  S16 POC (Corp).html
# Can't get commission gold:  7AHS008_170329_secret.html
# Can't get commission gold:  B-CODE JPHITA R01_01MAY16-31MAR17_161222_secret.html
# ...

# %%
comm_cluster = tfidf_cluster(comm, k=2, v_min_df=2)
comm[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check_JP.csv', index=False)
# Out:
# Number of features:  987

# %% [markdown]
# ### ME market

# %%
comm = get_market_comm(db, faresheet, 'ME')
# Out:
# Can't get commission gold:  2017_Corporate_PCC_Grid_BAH_Upd30Apr2017.html
# Can't get commission gold:  AMM_R17-03_(09Apr17)_eff_09Apr17-31Dec17.html
# Can't get commission gold:  BAH_R17-01_(18Jan17)_eff_01Feb17-31Dec17.html
# Can't get commission gold:  BAH_R17-07_(03MAY17)_wef_01Jun17-31Dec17_dep_01Jun17-31Mar18.html
# Can't get commission gold:  BAH_R17-09_(11Jul17)_wef_01Jun17-31Dec17_dep_01Jun17-31Mar18_(SOTO_Fare_Adjustment).html
# Can't get commission gold:  CAI_R17-01_(27Apr17)_eff_27Apr17-31Dec17_(For_Kanoo_Bahrain).html
# Can't get commission gold:  CAI_R17-03_(1Nov17)_eff_07Jun17-31Mar18_(KANOO)_(Sale_Travel_Validity_Extended).html
# Can't get commission gold:  DHA_R17-11_(11Jul17)_wef_01Jun17-31Dec17_dep_01Jun17-31Mar18_(SOTO_Fare_Adjustment).html
# Can't get commission gold:  UAE_PAB_R17-01_(18Jan17)_wef_01Feb17-31Dec17_dep_01Feb17-31Mar18.html
# Can't get commission gold:  UAE_PAB_R17-10_(30Apr17)_wef_15Apr17-31Dec17_dep_15Apr17-31Mar18_(GV2_relaunch).html
# ...

# %%
comm['filename'].iloc[0]
# Out:
# 'DHA_R17-15_(08Nov17)_wef_05Aug17-31Dec17_dep_05Aug17-31Mar18_(No_Commission_on_TH_SOTO_Fares).html'

# %% [markdown]
# ### HKCX market

# %%
comm = get_market_comm(db, faresheet, 'HKCX')
# Out:
# Can't get commission gold:  7HKA626-640FF730_secret.html
# Can't get commission gold:  7HKAD42-65FF701_secret.html
# Can't get commission gold:  7HKAI43-60FF701_secret.html
# Can't get commission gold:  7HKAO51-AO80FF709_secret.html
# Can't get commission gold:  HKG4246_B CODE HKOVARPZ_R20170329_Ove Arup 2017 - WTL_wef_01Apr17-31Mar18_secret.html
# Can't get commission gold:  HKG4260_B CODE HKPHMOIZ_R20170116_Philip Morris 2017 - CWT (update on ageement period till 30Nov18)_wef 01Jan17-30Nov18_secret.html
# Can't get commission gold:  HKG4272FF600.html
# Can't get commission gold:  HKG4280_B CODE HKBLOLPZ_R20170713_Bloomberg 2017 - BCD_wef_01Aug17-31Jul19_secret.html
# Can't get commission gold:  HKG4293_B CODE HKBASSEZ_R20170614_BASF 2017 - GBT_wef_01Jul17-30Jun19_secret.html
# Can't get commission gold:  HKG4300_B CODE HKCLSAXZ_R20170619_CLSA 2017- BCD_wef_01Jul17-30Jun18_secret.html
# ...

# %%
comm_cluster = tfidf_cluster(comm, k=3, v_min_df=2)
comm[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check_HKCX.csv', index=False)
# Out:
# Number of features:  1025

# %% [markdown]
# ### MY market

# %%
comm = get_market_comm(db, faresheet, 'MY')
# Out:
# Can't get commission gold:  KUL8148,8149FF509_R01_WEF 15FEB-21MAR17_DEP 15FEB-31AUG17_EXKUL MITF MAR17_AGT_secret.html
# Can't get commission gold:  KUL8174FF829_WEF 01MAY-30NOV17_DEP UNTIL 31DEC17_Airlink Cruise_secret.html
# Can't get commission gold:  MAL8545,8546FF600_BCODEMYCYSEMZ_WEF 01JAN-31DEC17_DEP UNTIL 31JAN18_Cypress Semiconductor_secret.html
# Can't get commission gold:  PEN8150FF509_IBE_R02_WEF 10-31JUL17_DEP 10JUL17-31JAN18_ExPEN MITM Promo_secret.html
# Can't get commission gold:  PEN8158FF509_WEF 11-31JAN17_DEP 11JAN-31MAR17_ExPEN New Year Deals_TA_secret.html
# Can't get commission gold:  PEN8160FF509_WEF 23-26MAR17_DEP 24MAR-24MAY17_ExPEN Weekend Flash Deals_TA_secret.html
# Can't get commission gold:  PEN8163FF509_R03_TA_WEF 24MAR-14MAY17_DEP 24MAR-31AUG17_ExPEN Fantastic Holiday Deals(removed TWN)_secret.html
# Can't get commission gold:  PEN8164FF509_R03_TA_WEF 24MAR-14MAY17_DEP 01SEP-30NOV17_ExPEN Fantastic Holiday Deals(removed TWN)_secret.html
# ...

# %%
comm_cluster = tfidf_cluster(comm, k=3, v_min_df=2)
comm[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check_MY.csv', index=False)
# Out:
# Number of features:  1394

# %% [markdown]
# ### US_OFFLINES market

# %%
comm = get_market_comm(db, faresheet, 'US_OFFLINES')
# Out:
# Can't get commission gold:  17MEX032-ORIG.Vamonoz_Viajes.html
# Can't get commission gold:  18MEX006-ORIG.Corporate_Travel_Services_(CTS).html
# Can't get commission gold:  SFO_ADHOC_2017-17SF037-040FF506.html
# Can't get commission gold:  17LAM115-ORIG.Viajes_Falabella.html
# Can't get commission gold:  17LAM152-ORIG.Century_Travel.html
# Can't get commission gold:  18MEX012-ORIG.Viajes_Intermex.html
# Can't get commission gold:  US_Adhoc_Grp_Report_2017-17USHXXGXFF706(07JUL-13JUL17).html
# Can't get commission gold:  15LAM130-ORIG.Viajes_Fidanque_-_American_Express.html
# Can't get commission gold:  16MEX028-ORIG.Touring_Plus_S.A._DE_C.V..html
# Can't get commission gold:  16MEX031ORIG.Visatur_S.A._DE_C.V..html
# Can't get commission gold:  17LAM102-ORIG_Travel_Gallery.html
# Can't get commission gold:  17LAM114-ORIG.Turismo_Cocha.html
# Can't get commission gold:  17MEX004-ORIG.Consolid_Mexico_S.A._de_C.V_.html
# Can't get commission gold:  15LAM127-ORIG.Leo_Tours.html
# ...

# %%
comm['cluster'] = 0
comm[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check_US_OFFLINES.csv', index=False)

# %% [markdown]
# ### PK market

# %%
comm = get_market_comm(db, faresheet, 'PK')
# Out:
# Can't get commission gold:  15PK360FF506.html
# Can't get commission gold:  15PK374FF506.html
# Can't get commission gold:  15PK380FF506.html
# Can't get commission gold:  15PK409FF506.html
# Can't get commission gold:  17PK005FF506.html
# Can't get commission gold:  17PK021FF506.html
# Can't get commission gold:  17PK036FF506.html
# Can't get commission gold:  17PK038FF506.html
# Can't get commission gold:  17PK111FF506.html
# Can't get commission gold:  17PK126FF506.html
# Can't get commission gold:  17PK131FF506.html
# Can't get commission gold:  17PK140FF506.html
# Can't get commission gold:  17PK148FF506.html
# Can't get commission gold:  17PK151FF506.html
# Can't get commission gold:  15PK391FF506.html
# Can't get commission gold:  15PK395FF506.html
# Can't get commission gold:  15PK396FF506.html
# Can't get commission gold:  15PK397FF506.html
# Can't get commission gold:  15PK428FF506.html
# Can't get commission gold:  17PK013FF506.html
# ...

# %%
comm['cluster'] = 0
comm[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check_PK.csv', index=False)

# %% [markdown]
# ### HKKA market

# %%
comm = get_market_comm(db, faresheet, 'HKKA')
# Out:
# Can't get commission gold:  HKM4038_bcode HKFIIN1Z HKFIIN2Z_wef_23Feb17 - 20Feb18.html
# Can't get commission gold:  HKM4042_bcode  HKLUHOIZ_wef_04Jul18 - 30Jun18.html
# Can't get commission gold:  HKM4043_bcode  HKCRAG1Z  HKCRAG2Z  HKCRAG3Z  HKCRAG4Z  HKCRAG5Z  HKCRAG6Z_wef_18Jul17 - 31Jul18.html
# Can't get commission gold:  HKM4046_bcode  HKNOMINZ_wef_29Sep17 - 30Sep18.html
# Can't get commission gold:  HKM4049_bcode  HKSOCO1Z HKSOCO2Z HKSOCO3Z HKSOCO4Z HKSOCO5Z_wef_17Mar17 - 31Mar18.html
# Can't get commission gold:  HKM4082_bcode  HKSTCHBZ_wef_19Jun17 - 31Jul18.html
# Can't get commission gold:  HKM4125_bcode  HKXXXXXZ_wef_15Sep16 - 31Oct17.html
# Can't get commission gold:  HKM4127_bcode  HKOREALZ_wef_12Oct17 - 31Mar18.html
# Can't get commission gold:  HKM4003_bcode  HKXINEAZ_dep_08Sep17 - 31Aug18.html
# Can't get commission gold:  HKM4024_bcode  HKPRUH1Z  HKPRUH2Z_wef_20Oct16 - 31Oct17.html
# Can't get commission gold:  HKM4027_bcode  HKMOSTCZ_wef_09May16 - 31May18.html
# ...

# %%
comm['cluster'] = 0
comm[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check_HKKA.csv', index=False)

# %% [markdown]
# ### IE market

# %%
comm = get_market_comm(db, faresheet, 'IE')
# Out:
# Can't get commission gold:  IRE-PUB_HKG-6F-YR_2017-19v2 R01 wef 20Apr17-31Mar18 dep 20Apr17-31Mar19.html
# Can't get commission gold:  IRE5500FF800-ITX-2017-19 R01 wef 28Apr17-31Mar18 dep 28Apr17-31Mar19.html
# Can't get commission gold:  IRE4655FF510-HK-PHP-CMN-2017-19 R01 wef 28Apr17-31Mar18 dep 28Apr17-31Mar19.html
# Can't get commission gold:  IRE2400FF500-HKG-6F-YR-2017-19 R01b wef 20Mar17-31Mar18 dep 20Mar17-31Mar19.html
# Can't get commission gold:  IRE5453FF802-IT-LWTP1-17 R01b wef 31Mar-04May17 dep 17Apr17-31Mar18.html
# Can't get commission gold:  IRE4699FF502-HK-CN-ASIA-SWP-LWTP1-17 R01a wef 31Mar-04May17 dep 17Apr17-31Mar18.html
# Can't get commission gold:  IRE2400FF500-HKG-6F-YR-2017-19v2 R02 wef 20Apr17-31Mar18 dep 20Apr17-31Mar19.html
# Can't get commission gold:  IRE4655FF510-HK-PHP-CMN-2017-19 R01a wef 28Apr17-31Mar18 dep 28Apr17-31Mar19.html
# Can't get commission gold:  IRE-PUB_HKG-6F-YR_2017-19v2 R02 wef 20Apr17-31Mar18 dep 20Apr17-31Mar19.html
# ...

# %%
choose_k(comm, k1=2, k2=10, v_min_df=5)
# Out:
# Number of features:  1438
# For n_clusters=2, The Silhouette Coefficient is 0.4377980869849158
# For n_clusters=3, The Silhouette Coefficient is 0.38009805361212734
# For n_clusters=4, The Silhouette Coefficient is 0.4782216274240481
# For n_clusters=5, The Silhouette Coefficient is 0.47907075586811426
# For n_clusters=6, The Silhouette Coefficient is 0.5129901138009377
# For n_clusters=7, The Silhouette Coefficient is 0.5109016406593023
# For n_clusters=8, The Silhouette Coefficient is 0.4902487496888944
# For n_clusters=9, The Silhouette Coefficient is 0.47473831693220947

# %%
comm_cluster = tfidf_cluster(comm, k=4, v_min_df=2)
comm_cluster[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check_IE.csv', index=False)
# Out:
# Number of features:  1631

# %% [markdown]
# # for country that looks like no commission, do sampling

# %%
def get_country_docs(country):
    us_docs = [doc for doc in db[faresheet].find({'country': country}, 
                                  {'predictions':1, 'classifications':1, 'path':1, 'teststring':1, 'filename':1, 'country':1})]
    us_df = pd.DataFrame(us_docs)
    return us_df

# %%
comm = get_country_docs('IL')

# %%
len(comm)
# Out:
# 175

# %%
choose_k(comm, k1=2, k2=20, v_min_df=5)
# Out:
# Number of features:  1259
# For n_clusters=2, The Silhouette Coefficient is 0.24781366312901984
# For n_clusters=3, The Silhouette Coefficient is 0.14350817836036978
# For n_clusters=4, The Silhouette Coefficient is 0.18418772242248946
# For n_clusters=5, The Silhouette Coefficient is 0.1725548144747011
# For n_clusters=6, The Silhouette Coefficient is 0.20079236248879356
# For n_clusters=7, The Silhouette Coefficient is 0.22284320809067196
# For n_clusters=8, The Silhouette Coefficient is 0.2215874134645615
# For n_clusters=9, The Silhouette Coefficient is 0.22979641432618877
# For n_clusters=10, The Silhouette Coefficient is 0.24120850657688728
# For n_clusters=11, The Silhouette Coefficient is 0.234665636188625
# For n_clusters=12, The Silhouette Coefficient is 0.23161035594146784
# For n_clusters=13, The Silhouette Coefficient is 0.2437327043194748
# For n_clusters=14, The Silhouette Coefficient is 0.2388114532434061
# ...

# %%
check_cols = ['filename', 'path', 'cluster', 'manual_check']

# %%
comm = tfidf_cluster(comm, k=13, v_min_df=3)
sample = sample_by_cluster(comm, k=13, sample_num=1)
sample['manual_check'] = ''
sample[check_cols].to_csv('/Users/chenjialu/Desktop/commission_check_IL.csv', index=False)
# Out:
# Number of features:  2040

# %% [markdown]
# ### BD market

# %%
from raxutil.ml.templateAnalysis import *
comm = get_market_comm(db, faresheet, 'BD')
# Out:
# Can't get commission gold:  CORP Sales.html
# Can't get commission gold:  16BD155-163FF506.html
# Can't get commission gold:  17BD001-006FF506.html
# Can't get commission gold:  17BD007FF506.html
# Can't get commission gold:  17BD008-011FF506.html
# Can't get commission gold:  17BD012-021FF506.html
# Can't get commission gold:  17BD022-032FF506_17BD029FF706.html
# Can't get commission gold:  17BD033-037FF506_17BD036FF706_17BD038FF706.html
# Can't get commission gold:  17BD039-045FF506.html
# Can't get commission gold:  17BD046-054FF506.html
# Can't get commission gold:  17BD056-059FF506_17BD055FF706.html
# Can't get commission gold:  17BD060-067FF506.html
# Can't get commission gold:  17BD068-082FF506_17BD079-081FF706.html
# Can't get commission gold:  17BD083-088FF506.html
# Can't get commission gold:  17BD089-094FF506.html
# Can't get commission gold:  17BD095-106FF506_17BD096FF706_17BD103FF706.html
# Can't get commission gold:  17BD109-113FF506_17BD107-108FF706.html
# ...

# %%
comm['manual_check'] = ''
comm[["filename", "country", "path", "gold", "pred"]].to_csv('/Users/chenjialu/Desktop/commission_check_BD.csv', index=False)

# %% [markdown]
# ### ME market

# %%
from raxutil.ml.templateAnalysis import *
comm = get_market_comm(db, faresheet, 'ME')
# Out:
# Can't get commission gold:  17AUH1341-1343.html
# Can't get commission gold:  17AUH1344-1349.html
# Can't get commission gold:  17AUH1350-1353.html
# Can't get commission gold:  17AUH1354-1356.html
# Can't get commission gold:  17AUH1357-1362.html
# Can't get commission gold:  17AUH1363-1372.html
# Can't get commission gold:  17AUH1373-1377.html
# Can't get commission gold:  17AUH1378-1379.html
# Can't get commission gold:  17AUH1380-1383.html
# Can't get commission gold:  17AUH1384.html
# Can't get commission gold:  17AUH1385-1392.html
# Can't get commission gold:  17AUH1393-1394.html
# Can't get commission gold:  17AUH1395.html
# Can't get commission gold:  17AUH1396-1397.html
# Can't get commission gold:  17AUH1398-1401.html
# Can't get commission gold:  17AUH1402-1408.html
# Can't get commission gold:  17AUH1409-1418.html
# Can't get commission gold:  17DXB7233-7236.html
# Can't get commission gold:  17DXB7237-7244.html
# Can't get commission gold:  17DXB7245-7254.html
# ...

# %%
for index, row in comm.iterrows():
    print(row["filename"])
# Out:
# DHA_R17-15_(08Nov17)_wef_05Aug17-31Dec17_dep_05Aug17-31Mar18_(No_Commission_on_TH_SOTO_Fares).html

# %% [markdown]
# ### Chinese Sheets

# %%
docs = [doc for doc in db[faresheet].find({'lang': 'zh-cn'}, 
         {'predictions':1, 'classifications':1, 'path':1, 'wordlist':1, 'filename':1, 'country':1})]
df = pd.DataFrame(docs)

# %%
df['wordlist']
# Out:
# 0       [公司, 客户, 旅行, 主, 协议, 本, 协议, 签订, 于, 年, 月, 日, 协议,...
# 1       [公司, 客户, 旅行, 主, 协议, 本, 协议, 签订, 于, 年, 月, 日, 协议,...
# 2       [公司, 客户, 旅行, 主, 协议, 本, 协议, 签订, 于, 年, 月, 日, 协议,...
# 3       [公司, 客户, 旅行, 主, 协议, 本, 协议, 签订, 于, 年, 月, 日, 协议,...
# 4       [公司, 客户, 旅行, 主, 协议, 本, 协议, 签订, 于, 年, 月, 日, 协议,...
# 5       [公司, 客户, 旅行, 主, 协议, 本, 协议, 签订, 于, 年, 月, 日, 协议,...
# 6       [公司, 客户, 旅行, 主, 协议, 本, 协议, 签订, 于, 年, 月, 日, 协议,...
# 7       [公司, 客户, 旅行, 主, 协议, 本, 协议, 签订, 于, 年, 月, 日, 协议,...
# 8       [公司, 客户, 旅行, 主, 协议, 本, 协议, 签订, 于, 年, 月, 日, 协议,...
# 9       [公司, 客户, 旅行, 主, 协议, 本, 协议, 签订, 于, 年, 月, 日, 协议,...
# 10      [公司, 客户, 旅行, 主, 协议, 本, 协议, 签订, 于, 年, 月, 日, 协议,...
# 11      [公司, 客户, 旅行, 主, 协议, 本, 协议, 签订, 于, 年, 月, 日, 协议,...
# 12      [公司, 客户, 旅行, 主, 协议, 本, 协议, 签订, 于, 年, 月, 日, 协议,...
# 13      [公司, 客户, 旅行, 主, 协议, 本, 协议, 签订, 于, 年, 月, 日, 协议,...
# 14      [公司, 客户, 旅行, 主, 协议, 本, 协议, 签订, 于, 年, 月, 日, 协议,...
# 15      [公司, 客户, 旅行, 主, 协议, 本, 协议, 签订, 于, 年, 月, 日, 协议,...
# ...

# %%
with open("/Users/chenjialu/Desktop/stopwords-zh.txt") as f:
    content = f.readlines()

# %%
stoplist = [s.replace("\n", "") for s in content]

# %%
# feature engineering
from sklearn.feature_extraction.text import TfidfVectorizer
def dummy_fun(doc):
    return doc
tfidf_vectorizer = TfidfVectorizer(
    min_df=20,
    analyzer='word',
    tokenizer=dummy_fun,
    preprocessor=dummy_fun,
    stop_words=['”', '', '&', '﹕'],
    token_pattern=None)  

tfidf = tfidf_vectorizer.fit_transform(df['wordlist'])
tfidf_feature_list = tfidf_vectorizer.get_feature_names()

# %%
len(tfidf_feature_list)
# Out:
# 1093

# %%
for n_cluster in range(2, 20):
    kmeans = KMeans(n_clusters=n_cluster).fit(tfidf)
    label = kmeans.labels_
    sil_coeff = silhouette_score(tfidf, label, metric='euclidean')
    print("For n_clusters={}, The Silhouette Coefficient is {}".format(n_cluster, sil_coeff))
# Out:
# For n_clusters=2, The Silhouette Coefficient is 0.12831782822843418
# For n_clusters=3, The Silhouette Coefficient is 0.036674091053534516
# For n_clusters=4, The Silhouette Coefficient is 0.04178296000232614
# For n_clusters=5, The Silhouette Coefficient is 0.02805184769881346
# For n_clusters=6, The Silhouette Coefficient is 0.005942981625370958
# For n_clusters=7, The Silhouette Coefficient is -0.028346990839901248
# For n_clusters=8, The Silhouette Coefficient is 0.01586793228351282
# For n_clusters=9, The Silhouette Coefficient is -0.04860690854741106
# For n_clusters=10, The Silhouette Coefficient is -0.044111008876527774
# For n_clusters=11, The Silhouette Coefficient is 0.011175707124606664
# For n_clusters=12, The Silhouette Coefficient is -0.03360758261560815
# For n_clusters=13, The Silhouette Coefficient is 0.0005809246512997371
# For n_clusters=14, The Silhouette Coefficient is -0.03144849851284572
# For n_clusters=15, The Silhouette Coefficient is 0.00178728826857701
# ...
