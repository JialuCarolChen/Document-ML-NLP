# %%
# %load_ext autoreload
# %autoreload 2
from raxutil.ml.templateAnalysis import *
from pymongo import MongoClient

# %%
# atlas_client=MongoClient('mongodb://gerald:heroku01@cluster0-shard-00-00-yvbwp.mongodb.net:27017,cluster0-shard-00-01-yvbwp.mongodb.net:27017,cluster0-shard-00-02-yvbwp.mongodb.net:27017/admin?replicaSet=Cluster0-shard-0&ssl=true')
# client=MongoClient('mongodb://gerald:heroku01@127.0.0.1:27017')
client = MongoClient("mongodb://raxPaper:vN9k32dXma@cluster0-shard-00-00-yvbwp.mongodb.net:27017,cluster0-shard-00-01-yvbwp.mongodb.net:27017,cluster0-shard-00-02-yvbwp.mongodb.net:27017/raxdb?replicaSet=Cluster0-shard-0&ssl=true&authSource=admin")
db=client.raxdb
faresheet = 'CXfaresheets_new'

# %% [markdown]
# ### US market

# %%
us_comm = get_market_comm(db, faresheet, 'US')
us_comm2 = get_market_comm(db, faresheet, 'US_OFFLINES')
# Out:
# Can't get commission gold:  S_AM_fare_template_20170222_-_SCL_I_class_fare.html
# Can't get commission gold:  17LAX700.Rev7.Student_contract_with_fare_ex_TW_IN_PH_HK_(hotsent_27Apr20....html
# Can't get commission gold:  18FLL888FF520-Orig._(Hotsent_18Jan18).html
# Can't get commission gold:  16USA001-rev5_Luxury_Tour_(hotsent_21Jul2016).html
# Can't get commission gold:  S_AM_fare_template_20161028_-_Add_missing_cities.html
# Can't get commission gold:  17LAX700.Rev9.Student_contract_with_fare_ex_TW_IN_PH_HK_(hotsent_26Jul20....html
# Can't get commission gold:  17NYC006-Orig.American_Express_Travel_&_Lifestyle_Services_(TLS).Richard_(DPS_Net_Fares)_(MAY17-JUN17).html
# Can't get commission gold:  17NYC006-Rev3.American_Express_Travel_&_Lifestyle_Services_(TLS).Richard_(DPS_Net_Fares)_(MAY17-JUN17).html
# Can't get commission gold:  16FLL888FF520_Rev1_(Hotsent_23Jun16).html
# Can't get commission gold:  16FLL888FF520_Rev2_(Hotsent_22Sep16).html
# ...

# %%
us_comm = pd.concat([us_comm, us_comm2])

# %%
# get the commission sheet for checking
us_comm_check_yes = us_comm.loc[us_comm["gold"]!="yes"]
us_comm_check_yes[[ 'country', 'filename', 'path', 'gold', 'pred' ]].to_csv("/Users/chenjialu/Desktop/commission_check_US.csv")

# %%
analyzer = ClusterAnalyzer()

# %%
analyzer.choose_k(us_comm, k1=15, k2=25, v_min_df=50)
# Out:
# Number of features:  2328
# For n_clusters=15, The Silhouette Coefficient is 0.3631718370097164
# For n_clusters=16, The Silhouette Coefficient is 0.45768006960198776
# For n_clusters=17, The Silhouette Coefficient is 0.34970195919677793
# For n_clusters=18, The Silhouette Coefficient is 0.371815951840051
# For n_clusters=19, The Silhouette Coefficient is 0.3869854179344724
# For n_clusters=20, The Silhouette Coefficient is 0.3813432839495634
# For n_clusters=21, The Silhouette Coefficient is 0.38581352626533655
# For n_clusters=22, The Silhouette Coefficient is 0.3711140946986125
# For n_clusters=23, The Silhouette Coefficient is 0.38102794128382605
# For n_clusters=24, The Silhouette Coefficient is 0.37277279959546694

# %%
us_comm = analyzer.find_clusters(us_comm, k=16, v_min_df=50)
# Out:
# Number of features:  2328

# %%
us_comm.head()
# Out:
#                           _id country  \
# 1    5b320fcbeb1c822898f01e5b      US
# 204  5b320fceeb1c822898f01e7c      US
# 266  5b320fcdeb1c822898f01e74      US
# 179  5b320fcdeb1c822898f01e78      US
# 205  5b320fd9eb1c822898f01eea      US
#
#                                               filename  \
# 1    Copy_of_USA_PUB_fare_template_-_20161128_-_SCL...
# 204  Resdistribution_of_Business_Class_-_USA_PUB_fa...
# 266  Resdistribution_of_Business_Class_-_USA_PUB_fa...
# 179  Resdistribution_of_Business_Class_-_USA_PUB_fa...
# 205  USA_PUB_fare_template_-_20160715_-_Extend_LT__...
#
#                                                   path  \
# 1    Z:\2017\US\Copy of USA PUB fare template - 201...
# 204  Z:\2017\US\Resdistribution of Business Class -...
# 266  Z:\2017\US\Resdistribution of Business Class -...
# 179  Z:\2017\US\Resdistribution of Business Class -...
# 205  Z:\2017\US\USA PUB fare template - 20160715 - ...
#
# ...

# %%
us_comm[[ 'country', 'filename', 'path', 'gold', 'pred', 'cluster' ]].to_csv("/Users/chenjialu/Desktop/commission_US_list_new.csv")

# %%
# update for production:
for index, row in us_comm.iterrows():
    db[faresheet].update_one({"_id": row["_id"]},
                            {"$set": {"case": "commission_production"}})

# %%
# check
comm_docs = [doc for doc in db[faresheet].find({"case": "commission_production"}, {"filename":1})]

# %%
len(comm_docs)
# Out:
# 520

# %%
# re-collect some training data after check
comm_df = pd.read_csv("/Users/chenjialu/Desktop/commission_US_list.csv")

# %%
comm_df[comm_df["manual check"]=="no"]
# Out:
#     country                                           filename  \
# 314      US  16NYC010-Rev1_Missionary_USA_wide_(Hotsent_22F...
# 326      US  17NYC010-Orig.Missionary_USA_wide_(Hotsent_11M...
# 327      US  17NYC010-Orig.Missionary_USA_wide_(Hotsent_pen...
# 379      US  USAMAXO-Rev2_Amazon_com_Inc__(formerly_3310875...
# 380      US  USAMAXO-Rev3.Amazon.com_Inc_(JUN17-SEP17)_3-mo...
# 381      US  USAMAXO-Rev4.Amazon.com_Inc_(OCT17).1-month_ex...
# 382      US  USAMAXO-Rev5.Amazon.com_Inc._(formerly_3310875...
# 383      US  USAMAXO-Rev8.Amazon_(MMA_US-POS)_(OCT17-JUL19)...
# 384      US   USULXLL-Rev6.UL_LLC_(SEP17-AUG19)_(Rebecca).html
# 397      US  USMASSE-Rev7.The_Boston_Consortium_for_Higher_...
#
#                                                   path gold pred  cluster  \
# 314  Z:\2017\US\16NYC010-Rev1 Missionary USA wide (...  NaN  yes        8
# 326  Z:\2017\US\17NYC010-Orig.Missionary USA wide (...  NaN  yes        8
# ...

# %%
# update for production:
for index, row in comm_df[comm_df["manual check"]=="no"].iterrows():
    db[faresheet].update_one({"country": row["country"], "filename": row["filename"]},
                            {"$set": {"case": "", "classifications.Commission":"no"}})
    print(row["filename"])
# Out:
# 16NYC010-Rev1_Missionary_USA_wide_(Hotsent_22Feb2017).html
# 17NYC010-Orig.Missionary_USA_wide_(Hotsent_11May2017).html
# 17NYC010-Orig.Missionary_USA_wide_(Hotsent_pending).html
# USAMAXO-Rev2_Amazon_com_Inc__(formerly_3310875Z)_Patricia_(OCT17-SEP19).html
# USAMAXO-Rev3.Amazon.com_Inc_(JUN17-SEP17)_3-month_extension_Patricia.html
# USAMAXO-Rev4.Amazon.com_Inc_(OCT17).1-month_extension.Patricia.html
# USAMAXO-Rev5.Amazon.com_Inc._(formerly_3310875Z).Patricia_(OCT17-SEP19).html
# USAMAXO-Rev8.Amazon_(MMA_US-POS)_(OCT17-JUL19)_Patricia.html
# USULXLL-Rev6.UL_LLC_(SEP17-AUG19)_(Rebecca).html
# USMASSE-Rev7.The_Boston_Consortium_for_Higher_Education_Inc._(Feb18-Jan.._.html

# %%
len(comm_df)
# Out:
# 398

# %% [markdown]
# ### Found that excel files with filename 'USA PUB fare template...' and sheet name '2016/2017 tactical' has commission information

# %%
# special docs
docs = [doc for doc in db[faresheet].find({"country":{"$in": ["US", "US_OFFLINES"]}}, 
                                           {"filename":1, "country":1, "teststring":1})]

# %%
docs_df = pd.DataFrame(docs)

# %%
# match these type of documents
mask1 = docs_df["filename"].str.contains("USA_PUB_fare_template")
mask2 = docs_df["teststring"].str.contains("10% Comm")
mask3 = docs_df["teststring"].str.contains("3% Comm")
mask4 = docs_df["teststring"].str.contains("USA888FF500")
# mask4 = [False if m else True for m in mask4]
docs_df[mask1&mask2&mask3&mask4]
for index, row in docs_df[mask1&mask2&mask3&mask4].iterrows():
    db[faresheet].update_one({"_id": row["_id"]},
                             {"$set": {"classifications.Commission": "yes"}})
    print(index, row["filename"])
# Out:
# 1 Copy_of_USA_PUB_fare_template_-_20161128_-_SCL_specials__DEC_Promo_60_AP_less_5____(00000002).html
# 2 USA_PUB_fare_template_-_20160719_-_NYC-BKK_HKT_CNX_Low_Season_N_class_fa___.html
# 3 USA_PUB_fare_template_-_20161027_-_I-AP_eff_04Nov__LT_E-AP_extended_to_(2).html
# 4 USA_PUB_fare_template_-_20161111_-_Include_new_TLV.html
# 5 USA_PUB_fare_template_-_20170109_-_EWRHKG_I_class_USD6723_7223_match_UA____.html
# 6 USA_PUB_fare_template_-_20170202_-_STL_MSP_CMH_I_class_fare.html
# 7 USA_PUB_fare_template_-_20170511_-_LAX-BKK_SIN_PEY_Summer_promo.html
# 8 USA_PUB_fare_template_-_20170714_-_LAM_I_class_special.html
# 9 USA_PUB_fare_template_-_20170725_-_Extend_LT_to_31Aug2017_for_India_S_N_....html
# 10 USA_PUB_fare_template_-_20170731_-_S18_SPCL.html
# 11 USA_PUB_fare_template_-_20170803_-_LAXHKG_EY_Post_Summer.html
# 28 USA_PUB_fare_template_-_20160720_-_Extend_LT_for_S_N_fares_to_14Aug_plus____(2).html
# 29 USA_PUB_fare_template_-_20160722_-_Change_LAXHKG_O_class_to_$403_$444.html
# ...

# %% [markdown]
# ### Re-collect after Manual check

# %%
comm = pd.read_csv("/Users/chenjialu/Desktop/commission_US_list_new.csv")

# %%
comm.head()
# Out:
#   country                                           filename gold pred  \
# 0      US  Copy_of_USA_PUB_fare_template_-_20161128_-_SCL...  yes  yes
# 1      US  Resdistribution_of_Business_Class_-_USA_PUB_fa...  NaN  yes
# 2      US  Resdistribution_of_Business_Class_-_USA_PUB_fa...  NaN  yes
# 3      US  Resdistribution_of_Business_Class_-_USA_PUB_fa...  NaN  yes
# 4      US  USA_PUB_fare_template_-_20160715_-_Extend_LT__...  yes  yes
#
#    cluster template manual check  \
# 0        0        C          yes
# 1        0        C           no
# 2        0        C           no
# 3        0        C           no
# 4        0        C          yes
#
#                                                 path
# 0  Z:\2017\US\Copy of USA PUB fare template - 201...
# 1  Z:\2017\US\Resdistribution of Business Class -...
# 2  Z:\2017\US\Resdistribution of Business Class -...
# 3  Z:\2017\US\Resdistribution of Business Class -...
# 4  Z:\2017\US\USA PUB fare template - 20160715 - ...

# %%
len(comm)
# Out:
# 541

# %%
for index, row in comm.iterrows():
    if row["manual check"] == "yes" or row["gold"] == "yes":
        db[faresheet].update_one({"filename": row["filename"], "country": row["country"]}, 
                                 {"$set": {"classifications.Commission": "yes",
                                          "template": row["template"],
                                          "case": "commission_production"}})
                       
    else:
        db[faresheet].update_one({"filename": row["filename"], "country": row["country"]}, 
                                 {"$set": {"classifications.Commission": "no"}})

# %% [markdown]
# ### AU, CA, TH market

# %%
comm = get_market_comm(db, faresheet, 'AU')
comm2 = get_market_comm(db, faresheet, 'CA')
comm3 = get_market_comm(db, faresheet, 'TH')
# Out:
# Can't get commission gold:  BCODEAUAERREZ_CTA_QLD_AERORESCUE_1603_2016_WEF 01MAR16-28FEB17_secret.html
# Can't get commission gold:  BCODEAUCARAUZ_CTA_QLD_CAREERS AUSTRALIA CTA 1602 SIGNED_WEF 01MAR16-28FEB17_secret.html
# Can't get commission gold:  BCODEAUGLENCZ_Glencore Contract Schedule 2017 - 19_WEF 01JUL17-30JUN19_secret.html
# Can't get commission gold:  BCODEAUHATCHZ_CTA_QLD_HATCH_Schedule 5 1609_2016_WEF 01SEP16-31AUG17_secret.html
# Can't get commission gold:  BCODEAUNEOME_CTA_WA_Neometals_2018 - signed_WEF 01JAN18-31DEC18_secret.html
# Can't get commission gold:  ADL_CNS_weekend_surcharge_AUD63_waive_15-29SEP.html
# Can't get commission gold:  BCODEAUAONAU_CTA_NSW_AON_AU_-CUTS_2016_Ver_3_2016_renewal_WEF_01NOV16-31OCT17.html
# Can't get commission gold:  BCODEAUBPCONZ_CTA_Template_-BP_AU_2016-CUTS_v2_WEF_01NOV16-31OCT18.html
# Can't get commission gold:  BCODEAUBRAMTZ_Global-British_American_Tobacco_Australia_Limited_WEF_01FEB16-31JAN18.html
# ...

# %%
comm_df = pd.concat([comm, comm2, comm3])

# %%
len(comm_df)
# Out:
# 154

# %%
analyzer = ClusterAnalyzer()
analyzer.choose_k(comm_df, k1=3, k2=10, v_min_df=20)
# Out:
# Number of features:  1687
# For n_clusters=3, The Silhouette Coefficient is 0.2542239625113981
# For n_clusters=4, The Silhouette Coefficient is 0.30535010511577687
# For n_clusters=5, The Silhouette Coefficient is 0.3272574264798268
# For n_clusters=6, The Silhouette Coefficient is 0.31876817759516424
# For n_clusters=7, The Silhouette Coefficient is 0.3425155375904281
# For n_clusters=8, The Silhouette Coefficient is 0.3628403663490489
# For n_clusters=9, The Silhouette Coefficient is 0.36479728005749246

# %%
analyzer.choose_k(comm_df, k1=10, k2=20, v_min_df=20)
# Out:
# Number of features:  1687
# For n_clusters=10, The Silhouette Coefficient is 0.39385464079852756
# For n_clusters=11, The Silhouette Coefficient is 0.40774149296430623
# For n_clusters=12, The Silhouette Coefficient is 0.4126537631121081
# For n_clusters=13, The Silhouette Coefficient is 0.4295516302297328
# For n_clusters=14, The Silhouette Coefficient is 0.4174417182055283
# For n_clusters=15, The Silhouette Coefficient is 0.43546809034430684
# For n_clusters=16, The Silhouette Coefficient is 0.4161223673296121
# For n_clusters=17, The Silhouette Coefficient is 0.4184755818179408
# For n_clusters=18, The Silhouette Coefficient is 0.4656224870078277
# For n_clusters=19, The Silhouette Coefficient is 0.431160802340625

# %%
analyzer.choose_k(comm_df, k1=20, k2=50, v_min_df=20)
# Out:
# Number of features:  1687
# For n_clusters=20, The Silhouette Coefficient is 0.4739693120709794
# For n_clusters=21, The Silhouette Coefficient is 0.4915367039075516
# For n_clusters=22, The Silhouette Coefficient is 0.46433541786823107
# For n_clusters=23, The Silhouette Coefficient is 0.47835256852483604
# For n_clusters=24, The Silhouette Coefficient is 0.4982126093342305
# For n_clusters=25, The Silhouette Coefficient is 0.48966138029946715
# For n_clusters=26, The Silhouette Coefficient is 0.48206006705107424
# For n_clusters=27, The Silhouette Coefficient is 0.49192068862036864
# For n_clusters=28, The Silhouette Coefficient is 0.5141578654779657
# For n_clusters=29, The Silhouette Coefficient is 0.5442679591293391
# For n_clusters=30, The Silhouette Coefficient is 0.5212414587519304
# For n_clusters=31, The Silhouette Coefficient is 0.5570332605208231
# For n_clusters=32, The Silhouette Coefficient is 0.562620283939726
# ...

# %%
comm_df = analyzer.find_clusters(comm_df, k=34, v_min_df=20)
# Out:
# Number of features:  1687

# %%
comm_df.columns
# Out:
# Index(['_id', 'country', 'filename', 'path', 'teststring', 'gold', 'pred',
#        'cluster'],
#       dtype='object')

# %%
comm_df.head()
# Out:
#                           _id country  \
# 252  5b31bd2eeb1c822d2c45f82c      CA
# 33   5b2b5bd6eb1c8206a8cda697      CA
# 222  5b3207cfeb1c822898efeb90      TH
# 272  5b3207d1eb1c822898efeb9d      TH
# 201  5b3207d3eb1c822898efebaa      TH
#
#                                               filename  \
# 252   CAN906FF501_R0-17_HKCBA_wef_01Sep17-01Jan18.html
# 33   ECDA961FF501 R0-17 Canadian Financial Mission ...
# 222  THA1250_THA1546-1547FF530_R4_(GROSS)_TH_Y17_St...
# 272  THA1250_THA1546-1547FF530_R5_(GROSS)_TH_Y17_St...
# 201  THA1250_THA1546-1547FF530_R6_(GROSS)_TH_Y17_St...
#
#                                                   path  \
# 252  Z:\2017\CA\CAN906FF501 R0-17 HKCBA wef 01Sep17...
# 33   Z:\2017\CA\ECDA961FF501 R0-17 Canadian Financi...
# 222  Z:\2017\TH\THA1250 THA1546-1547FF530 R4 (GROSS...
# 272  Z:\2017\TH\THA1250 THA1546-1547FF530 R5 (GROSS...
# 201  Z:\2017\TH\THA1250 THA1546-1547FF530 R6 (GROSS...
#
# ...

# %%
comm_df.loc[comm_df["gold"]!="yes"]
# Out:
#                           _id country  \
# 33   5b2b5bd6eb1c8206a8cda697      CA
# 474  5b31bd2feb1c822d2c45f8b7      CA
# 242  5b31bd2feb1c822d2c45f8b8      CA
# 323  5b31bd2feb1c822d2c45f8b9      CA
# 291  5b31bd2feb1c822d2c45f8ba      CA
# 475  5b31bd2feb1c822d2c45f8bb      CA
# 359  5b31bd2feb1c822d2c45f8bc      CA
# 243  5b31bd2feb1c822d2c45f8bd      CA
# 221  5b31bd2feb1c822d2c45f8be      CA
# 437  5b31bd2feb1c822d2c45f8bf      CA
# 476  5b31bd2feb1c822d2c45f8c0      CA
# 399  5b31bd2feb1c822d2c45f8c9      CA
# 478  5b31bd2feb1c822d2c45f8ca      CA
# 400  5b31bd2feb1c822d2c45f8cb      CA
# 261  5b31bd2feb1c822d2c45f8cc      CA
# 456  5b31bd2feb1c822d2c45f8cd      CA
# 324  5b31bd2feb1c822d2c45f8d2      CA
# 224  5b31bd2feb1c822d2c45f8d3      CA
# 276  5b31bd2feb1c822d2c45f8d4      CA
# 244  5b31bd2feb1c822d2c45f8d5      CA
# 379  5b31bd2feb1c822d2c45f8d6      CA
# 107  5b2b576deb1c8206a8cd9752      AU
# 298  5b2b575deb1c8206a8cd96d4      AU
# ...

# %%
target_cols = ['country', 'filename', 'path', 'gold', 'pred','cluster']
comm_df.loc[comm_df["gold"]!="yes"][target_cols].to_csv("/Users/chenjialu/Desktop/commission_check_AU_CA_TH.csv")

# %% [markdown]
# ### Re-collect commissions after manual check CA market

# %%
docs = [doc for doc in db[faresheet].find({"country":"CA", "classifications.Commission": "yes"},{"filename":1, "country":1, "teststring":1})]

# %%
docs_df = pd.DataFrame(docs)

# %%
analyzer = ClusterAnalyzer()
analyzer.choose_k(docs_df, k1=3, k2=20, v_min_df=5)
# Out:
# Number of features:  1393
# For n_clusters=3, The Silhouette Coefficient is 0.47444784863747785
# For n_clusters=4, The Silhouette Coefficient is 0.49494580795384974
# For n_clusters=5, The Silhouette Coefficient is 0.5143083359526838
# For n_clusters=6, The Silhouette Coefficient is 0.5550197348595394
# For n_clusters=7, The Silhouette Coefficient is 0.5929632750622654
# For n_clusters=8, The Silhouette Coefficient is 0.6238001960672306
# For n_clusters=9, The Silhouette Coefficient is 0.6385309712466636
# For n_clusters=10, The Silhouette Coefficient is 0.6740493514782079
# For n_clusters=11, The Silhouette Coefficient is 0.6794255607392731
# For n_clusters=12, The Silhouette Coefficient is 0.6837349786868462
# For n_clusters=13, The Silhouette Coefficient is 0.6860210563643787
# For n_clusters=14, The Silhouette Coefficient is 0.6829301977993759
# For n_clusters=15, The Silhouette Coefficient is 0.6860791556581614
# ...

# %%
docs_df = analyzer.find_clusters(docs_df, k=12, v_min_df=5)
# Out:
# Number of features:  1393

# %%
# output for manually identified template
docs_df[['filename', 'country', 'cluster']].to_csv('/Users/chenjialu/Desktop/CA_commission_data_v1.csv')

# %% [markdown]
# update the template analysis result:

# %%
docs_df = pd.read_csv('/Users/chenjialu/Desktop/CA_commission_data_v1.csv')

# %%
# update for production:
for index, row in docs_df.iterrows():
    db[faresheet].update_one({"filename": row["filename"], "country":row["country"]},
                            {"$set": {"template":row["template"], "case": "commission_production"}})
